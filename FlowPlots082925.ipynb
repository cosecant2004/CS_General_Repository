# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
filepath_200GeV = "/Users/christianschmidt/Desktop/trajectum-2.1/src/200GeV_FinalResult1_NoSmash_80000_500PJ.h5"
filepath_54GeV = "/Users/christianschmidt/Desktop/trajectum-2.1/src/54GeV_FinalResult1_NoSmash_80000_500PJ.h5"
filepath_27GeV = "/Users/christianschmidt/Desktop/trajectum-2.1/src/27GeV_FinalResult1_NoSmash_80000_400PJ.h5"
filepath_19GeV = "/Users/christianschmidt/Desktop/trajectum-2.1/src/19GeV_FinalResult1_NoSmash_80000_400PJ.h5"

c22_pt_binned_vals_dir = "v2chargedcumulantsptbinnedbrak2/STARTPC2/centralitybinned/values"
c22_pt_binned_uerr_dir = "v2chargedcumulantsptbinnedbrak2/STARTPC2/centralitybinned/uppererrors"
c22_pt_binned_lerr_dir = "v2chargedcumulantsptbinnedbrak2/STARTPC2/centralitybinned/lowererrors"
pt_bins_dir = "v2chargedcumulantsptbinnedbrak2/STARTPC2/centralitybinned/bin"
pt_dbins_dir = "v2chargedcumulantsptbinnedbrak2/STARTPC2/centralitybinned/dbin"

with h5py.File(filepath_200GeV, "r") as hdf:
    c22_pt_binned_vals = hdf[c22_pt_binned_vals_dir][:]
    c22_pt_binned_uerr=hdf[c22_pt_binned_uerr_dir][:]
    c22_pt_binned_lerr=hdf[c22_pt_binned_lerr_dir][:]
    pt_bins=hdf[pt_bins_dir][:]
    pt_dbins=hdf[pt_dbins_dir][:]

# %%
index0 = 16
index1 = 17
index2 = 7
index3 = 8
index4 = 9
index5 = 10
index6 = 11
index7 = 12
index8 = 13
indexMINBIAS = 0
print(pt_bins.shape)
print(c22_pt_binned_vals[index1,0,:].shape)
# Out:
# (13,)
# (13,)

# %%
#0-5% data
pt_bins_data_05 = [0.17,
0.302,
0.494,
0.693,
0.893,
1.09,
1.29,
1.49,
1.69,
1.89,
2.17,
2.57,
2.97,
3.37,
3.92,
5.06,
7.36]

v2_vals_data_05 = [0.00702,
0.00936,
0.0181,
0.0269,
0.0351,
0.0422,
0.0485,
0.0552,
0.0607,
0.0651,
0.0706,
0.0765,
0.0765,
0.0797,
0.0787,
0.0649,
0.135]

v2_errs_data_05 = [0.00041,
0.00018,
0.00019,
0.00024,
0.0003,
0.00038,
0.00048,
0.00061,
0.00079,
0.001,
0.001,
0.0017,
0.0028,
0.0045,
0.0058,
0.012,
0.04]

# %%
#10-20 data

pt_bins_data_1020 = pt_bins_data_05

v2_vals_data_1020 = [0.0129,
0.0225,
0.0411,
0.0582,
0.0735,
0.0872,
0.0998,
0.112,
0.123,
0.132,
0.145,
0.155,
0.163,
0.166,
0.156,
0.137,
0.0881]

v2_errs_data_1020 = [0.00034,
0.00015,
0.00017,
0.00021,
0.00026,
0.00033,
0.00042,
0.00054,
0.00069,
0.00089,
0.0009,
0.0015,
0.0024,
0.0038,
0.0047,
0.0086,
0.034]

# %%
#30-40% data
pt_bins_data_3040 = pt_bins_data_05

v2_vals_data_3040 = [0.0207,
0.0361,
0.0629,
0.0887,
0.112,
0.131,
0.15,
0.165,
0.181,
0.196,
0.205,
0.214,
0.219,
0.222,
0.211,
0.177,
0.179]

v2_errs_data_3040 = [0.00044,
0.0002,
0.00023,
0.0003,
0.00038,
0.00049,
0.00062,
0.0008,
0.001,
0.0013,
0.0013,
0.0021,
0.0034,
0.0052,
0.0061,
0.012,
0.042]

# %%
c22_pt_binned_err = (c22_pt_binned_uerr + c22_pt_binned_lerr) * 0.5 

v22_pt_binned_vals = np.sqrt(c22_pt_binned_vals)
v22_pt_binned_err = 0.5 * c22_pt_binned_err * (c22_pt_binned_vals) ** -0.5
# Out:
# /var/folders/mb/30yyqfg516jdbq01t3whp1r40000gn/T/ipykernel_2418/335604615.py:3: RuntimeWarning: invalid value encountered in sqrt
#   v22_pt_binned_vals = np.sqrt(c22_pt_binned_vals)
# /var/folders/mb/30yyqfg516jdbq01t3whp1r40000gn/T/ipykernel_2418/335604615.py:4: RuntimeWarning: divide by zero encountered in power
#   v22_pt_binned_err = 0.5 * c22_pt_binned_err * (c22_pt_binned_vals) ** -0.5
# /var/folders/mb/30yyqfg516jdbq01t3whp1r40000gn/T/ipykernel_2418/335604615.py:4: RuntimeWarning: invalid value encountered in power
#   v22_pt_binned_err = 0.5 * c22_pt_binned_err * (c22_pt_binned_vals) ** -0.5

# %%
plt.rcParams.update({"text.usetex": False, "mathtext.fontset": "cm", 
                     "font.family": "serif", "font.size": 12})
plt.figure(figsize=(8, 6), dpi=200)

# plt.errorbar(pt_bins,c22_pt_binned_vals[index0,0,:],yerr=np.abs(c22_pt_binned_err[index0,0,:]), capsize=5,fmt="o",color="black",
#              label="")
# plt.errorbar(pt_bins,c22_pt_binned_vals[index1,0,:],yerr=np.abs(c22_pt_binned_err[index1,0,:]), capsize=5,fmt="o",color="red")
# plt.errorbar(pt_bins,c22_pt_binned_vals[index2,0,:],yerr=np.abs(c22_pt_binned_err[index2,0,:]), capsize=5,fmt="o",color="orange")
# plt.errorbar(pt_bins,c22_pt_binned_vals[index3,0,:],yerr=np.abs(c22_pt_binned_err[index3,0,:]), capsize=5,fmt="o",color="green")
# plt.errorbar(pt_bins,c22_pt_binned_vals[index4,0,:],yerr=np.abs(c22_pt_binned_err[index4,0,:]), capsize=5,fmt="o",color="blue")
plt.errorbar(pt_bins,c22_pt_binned_vals[index0,0,:],yerr=np.abs(c22_pt_binned_err[index0,0,:]), capsize=5,fmt="o",color="blue",label="Trajectum, 0-5%")
plt.errorbar(pt_bins_data_05,v2_vals_data_05,yerr=np.abs(v2_errs_data_05), capsize=5,fmt="^",color="blue",label="Data, arXiv:0409033, 0-5%")
plt.errorbar(pt_bins,c22_pt_binned_vals[index2,0,:],yerr=np.abs(c22_pt_binned_err[index2,0,:]), capsize=5,fmt="o",color="red",label="Trajectum, 10-20%")
plt.errorbar(pt_bins_data_1020,v2_vals_data_1020,yerr=np.abs(v2_errs_data_1020), capsize=5,fmt="^",color="red",label="Data, arXiv:0409033, 10-20%")
plt.errorbar(pt_bins,c22_pt_binned_vals[index4,0,:],yerr=np.abs(c22_pt_binned_err[index4,0,:]), capsize=5,fmt="o",color="green",label="Trajectum, 30-40%")
plt.errorbar(pt_bins_data_3040,v2_vals_data_3040,yerr=np.abs(v2_errs_data_3040), capsize=5,fmt="^",color="green",label="Data, arXiv:0409033, 30-40%")
# plt.errorbar(pt_bins,c22_pt_binned_vals[index5,0,:],yerr=np.abs(c22_pt_binned_err[index5,0,:]), capsize=5,fmt="o",color="blue")
# plt.errorbar(pt_bins,c22_pt_binned_vals[index6,0,:],yerr=np.abs(c22_pt_binned_err[index6,0,:]), capsize=5,fmt="o",color="indigo")
# plt.errorbar(pt_bins,c22_pt_binned_vals[index7,0,:],yerr=np.abs(c22_pt_binned_err[index7,0,:]), capsize=5,fmt="o",color="violet")
plt.xlim([0,9])
plt.ylim([0,0.3])
plt.title("$v_2$ vs. $p_T$ at $\sqrt{s_{NN}}=200$ GeV")
plt.xlabel("$p_T$")
plt.ylabel("$v_2$")
plt.text(3.3,0.26, "Discrepancy may be attributed to the \ndifference in CE between data and Trajectum.\nTrend is in agreement.")
plt.legend(prop={'size': '8'},loc="upper left")
plt.grid()
# Out:
# <>:22: SyntaxWarning: invalid escape sequence '\s'
# <>:22: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/mb/30yyqfg516jdbq01t3whp1r40000gn/T/ipykernel_2418/3822717671.py:22: SyntaxWarning: invalid escape sequence '\s'
#   plt.title("$v_2$ vs. $p_T$ at $\sqrt{s_{NN}}=200$ GeV")

# %%
v22_vals_dir = "v2chargedcumulantsbrak2/STARTPC2/centralitybinned/values"
v22_uerr_dir = "v2chargedcumulantsbrak2/STARTPC2/centralitybinned/uppererrors"
v22_lerr_dir = "v2chargedcumulantsbrak2/STARTPC2/centralitybinned/lowererrors"
v24_vals_dir = "v2chargedcumulantsbrak4/STARTPC2/centralitybinned/values"
v24_uerr_dir = "v2chargedcumulantsbrak4/STARTPC2/centralitybinned/uppererrors"
v24_lerr_dir = "v2chargedcumulantsbrak4/STARTPC2/centralitybinned/lowererrors"
centrality_dir = "centrality"

with h5py.File(filepath_200GeV, "r") as hdf:
    v22_vals_200GeV_Trajectum = hdf[v22_vals_dir][:]
    v22_uerr_200GeV_Trajectum = hdf[v22_uerr_dir][:]
    v22_lerr_200GeV_Trajectum = hdf[v22_lerr_dir][:]
    v24_vals_200GeV_Trajectum = hdf[v24_vals_dir][:]
    v24_uerr_200GeV_Trajectum = hdf[v24_uerr_dir][:]
    v24_lerr_200GeV_Trajectum = hdf[v24_lerr_dir][:]
    centrality = hdf[centrality_dir][:]

with h5py.File(filepath_54GeV, "r") as hdf:
    v22_vals_54GeV_Trajectum = hdf[v22_vals_dir][:]
    v22_uerr_54GeV_Trajectum = hdf[v22_uerr_dir][:]
    v22_lerr_54GeV_Trajectum = hdf[v22_lerr_dir][:]
    v24_vals_54GeV_Trajectum = hdf[v24_vals_dir][:]
    v24_uerr_54GeV_Trajectum = hdf[v24_uerr_dir][:]
    v24_lerr_54GeV_Trajectum = hdf[v24_lerr_dir][:]

with h5py.File(filepath_27GeV, "r") as hdf:
    v22_vals_27GeV_Trajectum = hdf[v22_vals_dir][:]
    v22_uerr_27GeV_Trajectum = hdf[v22_uerr_dir][:]
    v22_lerr_27GeV_Trajectum = hdf[v22_lerr_dir][:]
    v24_vals_27GeV_Trajectum = hdf[v24_vals_dir][:]
    v24_uerr_27GeV_Trajectum = hdf[v24_uerr_dir][:]
    v24_lerr_27GeV_Trajectum = hdf[v24_lerr_dir][:]

with h5py.File(filepath_19GeV, "r") as hdf:
    v22_vals_19GeV_Trajectum = hdf[v22_vals_dir][:]
    v22_uerr_19GeV_Trajectum = hdf[v22_uerr_dir][:]
    v22_lerr_19GeV_Trajectum = hdf[v22_lerr_dir][:]
    v24_vals_19GeV_Trajectum = hdf[v24_vals_dir][:]
    v24_uerr_19GeV_Trajectum = hdf[v24_uerr_dir][:]
    v24_lerr_19GeV_Trajectum = hdf[v24_lerr_dir][:]

centrality_bins_200GeV = np.genfromtxt("/Users/christianschmidt/Downloads/200GeVv22v23.csv", delimiter=",", skip_header=9, usecols=0, invalid_raise=False)
centrality_bins_200GeV = centrality_bins_200GeV[:-88]
v22_vals_200GeV = np.genfromtxt("/Users/christianschmidt/Downloads/200GeVv22v23.csv", delimiter=",", skip_header=9, usecols=1, invalid_raise=False)
v22_vals_200GeV = v22_vals_200GeV[:-88]
v22_staterrs_200GeV = np.genfromtxt("/Users/christianschmidt/Downloads/200GeVv22v23.csv", delimiter=",", skip_header=9, usecols=2, invalid_raise=False)
v22_staterrs_200GeV = v22_staterrs_200GeV[:-88]
v22_syserrs_200GeV = np.genfromtxt("/Users/christianschmidt/Downloads/200GeVv22v23.csv", delimiter=",", skip_header=9, usecols=4, invalid_raise=False)
v22_syserrs_200GeV = v22_syserrs_200GeV[:-88]

v22_errors_200GeV = (v22_staterrs_200GeV**2+ v22_syserrs_200GeV**2 ) ** 0.5

v24_vals_200GeV = np.genfromtxt("/Users/christianschmidt/Downloads/200GeVv22v23.csv", delimiter=",", skip_header=33, usecols=1, invalid_raise=False)
v24_vals_200GeV = v24_vals_200GeV[:-66]
v24_staterrs_200GeV = np.genfromtxt("/Users/christianschmidt/Downloads/200GeVv22v23.csv", delimiter=",", skip_header=33, usecols=2, invalid_raise=False)
v24_staterrs_200GeV = v24_staterrs_200GeV[:-66]
v24_syserrs_200GeV = np.genfromtxt("/Users/christianschmidt/Downloads/200GeVv22v23.csv", delimiter=",", skip_header=33, usecols=4, invalid_raise=False)
v24_syserrs_200GeV = v24_syserrs_200GeV[:-66]

v24_errors_200GeV = (v24_staterrs_200GeV**2+ v24_syserrs_200GeV**2 ) ** 0.5


centrality_bins_54GeV = np.genfromtxt("/Users/christianschmidt/Downloads/54GeVv22v23.csv", delimiter=",", skip_header=9, usecols=0, invalid_raise=False)
centrality_bins_54GeV = centrality_bins_54GeV[:-84]
v22_vals_54GeV = np.genfromtxt("/Users/christianschmidt/Downloads/54GeVv22v23.csv", delimiter=",", skip_header=9, usecols=1, invalid_raise=False)
v22_vals_54GeV = v22_vals_54GeV[:-84]
v22_staterrs_54GeV = np.genfromtxt("/Users/christianschmidt/Downloads/54GeVv22v23.csv", delimiter=",", skip_header=9, usecols=2, invalid_raise=False)
v22_staterrs_54GeV = v22_staterrs_54GeV[:-84]
v22_syserrs_54GeV = np.genfromtxt("/Users/christianschmidt/Downloads/54GeVv22v23.csv", delimiter=",", skip_header=9, usecols=4, invalid_raise=False)
v22_syserrs_54GeV = v22_syserrs_54GeV[:-84]

v22_errors_54GeV = (v22_staterrs_54GeV**2+ v22_syserrs_54GeV**2 ) ** 0.5

v24_vals_54GeV = np.genfromtxt("/Users/christianschmidt/Downloads/54GeVv22v23.csv", delimiter=",", skip_header=32, usecols=1, invalid_raise=False)
v24_vals_54GeV = v24_vals_54GeV[:-63]
v24_staterrs_54GeV = np.genfromtxt("/Users/christianschmidt/Downloads/54GeVv22v23.csv", delimiter=",", skip_header=32, usecols=2, invalid_raise=False)
v24_staterrs_54GeV = v24_staterrs_54GeV[:-63]
v24_syserrs_54GeV = np.genfromtxt("/Users/christianschmidt/Downloads/54GeVv22v23.csv", delimiter=",", skip_header=32, usecols=4, invalid_raise=False)
v24_syserrs_54GeV = v24_syserrs_54GeV[:-63]

v24_errors_54GeV = (v24_staterrs_54GeV**2+ v24_syserrs_54GeV**2 ) ** 0.5

centrality_bins_27GeV = np.genfromtxt("/Users/christianschmidt/Downloads/27GeVv22v23.csv", delimiter=",", skip_header=9, usecols=0, invalid_raise=False)
centrality_bins_27GeV = centrality_bins_27GeV[:-76]
v22_vals_27GeV = np.genfromtxt("/Users/christianschmidt/Downloads/27GeVv22v23.csv", delimiter=",", skip_header=9, usecols=1, invalid_raise=False)
v22_vals_27GeV = v22_vals_27GeV[:-76]
v22_staterrs_27GeV = np.genfromtxt("/Users/christianschmidt/Downloads/27GeVv22v23.csv", delimiter=",", skip_header=9, usecols=2, invalid_raise=False)
v22_staterrs_27GeV = v22_staterrs_27GeV[:-76]
v22_syserrs_27GeV = np.genfromtxt("/Users/christianschmidt/Downloads/27GeVv22v23.csv", delimiter=",", skip_header=9, usecols=4, invalid_raise=False)
v22_syserrs_27GeV = v22_syserrs_27GeV[:-76]

v22_errors_27GeV = (v22_staterrs_27GeV**2+ v22_syserrs_27GeV**2 ) ** 0.5

v24_vals_27GeV = np.genfromtxt("/Users/christianschmidt/Downloads/27GeVv22v23.csv", delimiter=",", skip_header=30, usecols=1, invalid_raise=False)
v24_vals_27GeV = v24_vals_27GeV[:-57]
v24_staterrs_27GeV = np.genfromtxt("/Users/christianschmidt/Downloads/27GeVv22v23.csv", delimiter=",", skip_header=30, usecols=2, invalid_raise=False)
v24_staterrs_27GeV = v24_staterrs_27GeV[:-57]
v24_syserrs_27GeV = np.genfromtxt("/Users/christianschmidt/Downloads/27GeVv22v23.csv", delimiter=",", skip_header=30, usecols=4, invalid_raise=False)
v24_syserrs_27GeV = v24_syserrs_27GeV[:-57]

v24_errors_27GeV = (v24_staterrs_27GeV**2+ v24_syserrs_27GeV**2 ) ** 0.5

centrality_bins_19GeV = np.genfromtxt("/Users/christianschmidt/Downloads/19GeVv22v23.csv", delimiter=",", skip_header=9, usecols=0, invalid_raise=False)
centrality_bins_19GeV = centrality_bins_19GeV[:-20]
v22_vals_19GeV = np.genfromtxt("/Users/christianschmidt/Downloads/19GeVv22v23.csv", delimiter=",", skip_header=9, usecols=1, invalid_raise=False)
v22_vals_19GeV = v22_vals_19GeV[:-20]
v22_staterrs_19GeV = np.genfromtxt("/Users/christianschmidt/Downloads/19GeVv22v23.csv", delimiter=",", skip_header=9, usecols=2, invalid_raise=False)
v22_staterrs_19GeV = v22_staterrs_19GeV[:-20]
v22_syserrs_19GeV = np.genfromtxt("/Users/christianschmidt/Downloads/19GeVv22v23.csv", delimiter=",", skip_header=9, usecols=4, invalid_raise=False)
v22_syserrs_19GeV = v22_syserrs_19GeV[:-20]

v22_errors_19GeV = (v22_staterrs_19GeV**2+ v22_syserrs_19GeV**2 ) ** 0.5

v24_vals_19GeV = np.genfromtxt("/Users/christianschmidt/Downloads/19GeVv22v23.csv", delimiter=",", skip_header=21, usecols=1, invalid_raise=False)
v24_vals_19GeV = v24_vals_19GeV[:-10]
v24_staterrs_19GeV = np.genfromtxt("/Users/christianschmidt/Downloads/19GeVv22v23.csv", delimiter=",", skip_header=21, usecols=2, invalid_raise=False)
v24_staterrs_19GeV = v24_staterrs_19GeV[:-10]
v24_syserrs_19GeV = np.genfromtxt("/Users/christianschmidt/Downloads/19GeVv22v23.csv", delimiter=",", skip_header=21, usecols=4, invalid_raise=False)
v24_syserrs_19GeV = v24_syserrs_19GeV[:-10]

v24_errors_19GeV = (v22_staterrs_19GeV**2+ v22_syserrs_19GeV**2 ) ** 0.5

# %%
print(centrality_bins_19GeV.shape)
print(v24_vals_19GeV)
print(v24_vals_19GeV.shape)
# Out:
# (9,)
# [0.0449 0.0483 0.0514 0.0516 0.0517 0.0496 0.0458 0.0383 0.026 ]
# (9,)

# %%
plt.rcParams.update({"text.usetex": False, "mathtext.fontset": "cm", 
                     "font.family": "serif", "font.size": 12})
plt.figure(figsize=(8, 6), dpi=200)

plt.errorbar(centrality_bins_200GeV,v22_vals_200GeV,yerr=v22_errors_200GeV, capsize=5,fmt="^",color="blue",label="STAR data (arXiv:2201.10365), 200 GeV")
plt.errorbar(centrality.ravel(),v22_vals_200GeV_Trajectum.ravel(),yerr=np.abs([v22_lerr_200GeV_Trajectum.ravel(),v22_uerr_200GeV_Trajectum.ravel()]), capsize=5,fmt="o",color="blue",label="Trajectum, 200 GeV")

plt.errorbar(centrality_bins_54GeV,v22_vals_54GeV,yerr=v22_errors_54GeV, capsize=5,fmt="^",color="red",label="STAR data (arXiv:2201.10365), 54.4 GeV")
plt.errorbar(centrality.ravel(),v22_vals_54GeV_Trajectum.ravel(),yerr=np.abs([v22_lerr_54GeV_Trajectum.ravel(),v22_uerr_54GeV_Trajectum.ravel()]), capsize=5,fmt="o",color="red",label="Trajectum, 54.4 GeV")

plt.errorbar(centrality_bins_27GeV,v22_vals_27GeV,yerr=v22_errors_27GeV, capsize=5,fmt="^",color="green",label="STAR data (arXiv:2201.10365), 27 GeV")
plt.errorbar(centrality.ravel(),v22_vals_27GeV_Trajectum.ravel(),yerr=np.abs([v22_lerr_27GeV_Trajectum.ravel(),v22_uerr_27GeV_Trajectum.ravel()]), capsize=5,fmt="o",color="green",label="Trajectum, 27 GeV")

plt.errorbar(centrality_bins_19GeV,v22_vals_19GeV,yerr=v22_errors_19GeV, capsize=5,fmt="^",color="purple",label="STAR data (arXiv:2201.10365), 19.6 GeV")
plt.errorbar(centrality.ravel(),v22_vals_19GeV_Trajectum.ravel(),yerr=np.abs([v22_lerr_19GeV_Trajectum.ravel(),v22_uerr_19GeV_Trajectum.ravel()]), capsize=5,fmt="o",color="purple",label="Trajectum, 19.6 GeV")

plt.axvline(x=min(centrality_bins_200GeV),linestyle="--",label="Most central bin from 200 GeV data",color="blue")
plt.axvline(x=min(centrality_bins_54GeV),linestyle="--",label="Most central bin from 54.4 GeV data",color="red")
plt.axvline(x=min(centrality_bins_27GeV),linestyle="--",label="Most central bin from 27 GeV data",color="green")
plt.axvline(x=min(centrality_bins_19GeV),linestyle="--",label="Most central bin from 19.6 GeV data",color="purple")

plt.xlabel("Centrality (%)")
plt.ylabel("$v_2\{2\}$")
plt.xlim([0,67.5])
plt.ylim([0.01,0.145])
plt.legend(prop={'size': '8'},loc="upper left")
plt.grid()
plt.title("$\sqrt{s_{NN}}$-Evolution of $v_2\{2\}$")
# Out:
# <>:23: SyntaxWarning: invalid escape sequence '\{'
# <>:28: SyntaxWarning: invalid escape sequence '\s'
# <>:23: SyntaxWarning: invalid escape sequence '\{'
# <>:28: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/mb/30yyqfg516jdbq01t3whp1r40000gn/T/ipykernel_2418/1213144217.py:23: SyntaxWarning: invalid escape sequence '\{'
#   plt.ylabel("$v_2\{2\}$")
# /var/folders/mb/30yyqfg516jdbq01t3whp1r40000gn/T/ipykernel_2418/1213144217.py:28: SyntaxWarning: invalid escape sequence '\s'
#   plt.title("$\sqrt{s_{NN}}$-Evolution of $v_2\{2\}$")
# Text(0.5, 1.0, '$\\sqrt{s_{NN}}$-Evolution of $v_2\\{2\\}$')

# %%
centrality_selection_mask = (centrality<1) & (centrality>0.05)

v22_vals_200GeV_Trajectum_mask = v22_vals_200GeV_Trajectum[centrality_selection_mask]
v22_symerr_200GeV_Trajectum_mask = 0.5*(v22_lerr_200GeV_Trajectum+v22_uerr_200GeV_Trajectum)[centrality_selection_mask]

mean_v22_200GeV_UCC=np.mean(v22_vals_200GeV_Trajectum_mask)
mean_v22_200GeV_UCC_err = np.sum(np.sqrt(v22_symerr_200GeV_Trajectum_mask**2))/len(v22_symerr_200GeV_Trajectum_mask)



v22_vals_54GeV_Trajectum_mask = v22_vals_54GeV_Trajectum[centrality_selection_mask]
v22_symerr_54GeV_Trajectum_mask = 0.5*(v22_lerr_54GeV_Trajectum+v22_uerr_54GeV_Trajectum)[centrality_selection_mask]

mean_v22_54GeV_UCC=np.mean(v22_vals_54GeV_Trajectum_mask)
mean_v22_54GeV_UCC_err = np.sum(np.sqrt(v22_symerr_54GeV_Trajectum_mask**2))/len(v22_symerr_54GeV_Trajectum_mask)



v22_vals_27GeV_Trajectum_mask = v22_vals_27GeV_Trajectum[centrality_selection_mask]
v22_symerr_27GeV_Trajectum_mask = 0.5*(v22_lerr_27GeV_Trajectum+v22_uerr_27GeV_Trajectum)[centrality_selection_mask]

mean_v22_27GeV_UCC=np.mean(v22_vals_27GeV_Trajectum_mask)
mean_v22_27GeV_UCC_err = np.sum(np.sqrt(v22_symerr_27GeV_Trajectum_mask**2))/len(v22_symerr_27GeV_Trajectum_mask)



v22_vals_19GeV_Trajectum_mask = v22_vals_19GeV_Trajectum[centrality_selection_mask]
v22_symerr_19GeV_Trajectum_mask = 0.5*(v22_lerr_19GeV_Trajectum+v22_uerr_19GeV_Trajectum)[centrality_selection_mask]

mean_v22_19GeV_UCC=np.mean(v22_vals_19GeV_Trajectum_mask)
mean_v22_19GeV_UCC_err = np.sum(np.sqrt(v22_symerr_19GeV_Trajectum_mask**2))/len(v22_symerr_19GeV_Trajectum_mask)

print(mean_v22_27GeV_UCC)
print(mean_v22_27GeV_UCC_err)
print(mean_v22_27GeV_UCC+mean_v22_27GeV_UCC_err)
print(v22_symerr_27GeV_Trajectum_mask)
# Out:
# 0.020074067202320467
# 0.00079767534
# 0.020871742542756866
# [[0.00033015]
#  [0.00122677]
#  [0.00096488]
#  [0.00109069]
#  [0.00080387]
#  [0.00067318]
#  [0.00049419]]

# %%
plt.rcParams.update({"text.usetex": False, "mathtext.fontset": "cm", 
                     "font.family": "serif", "font.size": 12})
plt.figure(figsize=(8, 6), dpi=200)

x_errorbands = np.linspace(0,5,1000)

plt.errorbar(centrality.ravel(),v22_vals_200GeV_Trajectum.ravel(),yerr=np.abs([v22_lerr_200GeV_Trajectum.ravel(),v22_uerr_200GeV_Trajectum.ravel()]), capsize=5,fmt="o",color="blue",label="Trajectum, 200 GeV")

plt.errorbar(centrality.ravel(),v22_vals_54GeV_Trajectum.ravel(),yerr=np.abs([v22_lerr_54GeV_Trajectum.ravel(),v22_uerr_54GeV_Trajectum.ravel()]), capsize=5,fmt="o",color="red",label="Trajectum, 54.4 GeV")

plt.errorbar(centrality.ravel(),v22_vals_27GeV_Trajectum.ravel(),yerr=np.abs([v22_lerr_27GeV_Trajectum.ravel(),v22_uerr_27GeV_Trajectum.ravel()]), capsize=5,fmt="o",color="green",label="Trajectum, 27 GeV")

plt.errorbar(centrality.ravel(),v22_vals_19GeV_Trajectum.ravel(),yerr=np.abs([v22_lerr_19GeV_Trajectum.ravel(),v22_uerr_19GeV_Trajectum.ravel()]), capsize=5,fmt="o",color="purple",label="Trajectum, 19.6 GeV")

plt.axhline(y=mean_v22_200GeV_UCC,linestyle="-",label=f"$\sqrt{{s_{{NN}}}}=200$ GeV, $v_2\{{2\}}_{{mean\>UCC}}={mean_v22_200GeV_UCC:.4f}\pm{mean_v22_200GeV_UCC_err:.4f}$",color="blue")
plt.fill_between(x_errorbands, mean_v22_200GeV_UCC-mean_v22_200GeV_UCC_err, mean_v22_200GeV_UCC+mean_v22_200GeV_UCC_err, color="blue", alpha=0.3)


plt.axhline(y=mean_v22_54GeV_UCC,linestyle="-",label=f"$\sqrt{{s_{{NN}}}}=54.4$ GeV, $v_2\{{2\}}_{{mean\>UCC}}={mean_v22_54GeV_UCC:.4f}\pm{mean_v22_54GeV_UCC_err:.4f}$",color="red")
plt.fill_between(x_errorbands, mean_v22_54GeV_UCC-mean_v22_54GeV_UCC_err, mean_v22_54GeV_UCC+mean_v22_54GeV_UCC_err, color="red", alpha=0.3)

plt.axhline(y=mean_v22_27GeV_UCC,linestyle="-",label=f"$\sqrt{{s_{{NN}}}}=27$ GeV, $v_2\{{2\}}_{{mean\>UCC}}={mean_v22_27GeV_UCC:.4f}\pm{mean_v22_27GeV_UCC_err:.4f}$",color="green")
plt.fill_between(x_errorbands, mean_v22_27GeV_UCC-mean_v22_27GeV_UCC_err, mean_v22_27GeV_UCC+mean_v22_27GeV_UCC_err, color="green", alpha=0.3)

plt.axhline(y=mean_v22_19GeV_UCC,linestyle="-",label=f"$\sqrt{{s_{{NN}}}}=19.6$ GeV, $v_2\{{2\}}_{{mean\>UCC}}={mean_v22_19GeV_UCC:.4f}\pm{mean_v22_19GeV_UCC_err:.4f}$",color="purple")
plt.fill_between(x_errorbands, mean_v22_19GeV_UCC-mean_v22_19GeV_UCC_err, mean_v22_19GeV_UCC+mean_v22_19GeV_UCC_err, color="purple", alpha=0.3)

plt.xlabel("Centrality (%)")
plt.ylabel("$v_2\{2\}$")
plt.xlim([0,1])
plt.ylim([0.015,0.065])
plt.ylim([0.015,0.03])
plt.legend(prop={'size': '8'},loc="upper left")
plt.grid()
plt.title("$\sqrt{s_{NN}}$-Evolution of $v_2\{2\}$")
# Out:
# <string>:15: SyntaxWarning: invalid escape sequence '\{'
# <string>:15: SyntaxWarning: invalid escape sequence '\}'
# <string>:19: SyntaxWarning: invalid escape sequence '\{'
# <string>:19: SyntaxWarning: invalid escape sequence '\}'
# <string>:22: SyntaxWarning: invalid escape sequence '\{'
# <string>:22: SyntaxWarning: invalid escape sequence '\}'
# <string>:25: SyntaxWarning: invalid escape sequence '\{'
# <string>:25: SyntaxWarning: invalid escape sequence '\}'
# <>:15: SyntaxWarning: invalid escape sequence '\{'
# <>:15: SyntaxWarning: invalid escape sequence '\}'
# <>:15: SyntaxWarning: invalid escape sequence '\s'
# <>:15: SyntaxWarning: invalid escape sequence '\>'
# <>:15: SyntaxWarning: invalid escape sequence '\p'
# <>:19: SyntaxWarning: invalid escape sequence '\{'
# <>:19: SyntaxWarning: invalid escape sequence '\}'
# <>:19: SyntaxWarning: invalid escape sequence '\s'
# <>:19: SyntaxWarning: invalid escape sequence '\>'
# ...

# %%
print(min(centrality_bins_54GeV))
print(centrality_bins_54GeV)
# Out:
# 2.0
# [62. 56. 51. 48. 46. 43. 41. 39. 36. 32. 29. 27. 23. 20. 17. 15. 12. 11.
#   7.  2.]

# %%
plt.rcParams.update({"text.usetex": False, "mathtext.fontset": "cm", 
                     "font.family": "serif", "font.size": 12})
plt.figure(figsize=(8, 6), dpi=200)

plt.errorbar(centrality_bins_200GeV,v24_vals_200GeV,yerr=v24_errors_200GeV, capsize=5,fmt="^",color="blue",label="STAR data (arXiv:2201.10365), 200 GeV")
plt.errorbar(centrality.ravel(),v24_vals_200GeV_Trajectum.ravel(),yerr=np.abs([v24_lerr_200GeV_Trajectum.ravel(),v24_uerr_200GeV_Trajectum.ravel()]), capsize=5,fmt="o",color="blue",label="Trajectum, 200 GeV")

plt.errorbar(centrality_bins_54GeV,v24_vals_54GeV,yerr=v24_errors_54GeV, capsize=5,fmt="^",color="red",label="STAR data (arXiv:2201.10365), 54.4 GeV")
plt.errorbar(centrality.ravel(),v24_vals_54GeV_Trajectum.ravel(),yerr=np.abs([v24_lerr_54GeV_Trajectum.ravel(),v24_uerr_54GeV_Trajectum.ravel()]), capsize=5,fmt="o",color="red",label="Trajectum, 54.4 GeV")

# plt.errorbar(centrality_bins_27GeV,v24_vals_27GeV,yerr=v24_errors_27GeV, capsize=5,fmt="^",color="green",label="STAR data (arXiv:2201.10365), 27 GeV")
# plt.errorbar(centrality.ravel(),v24_vals_27GeV_Trajectum.ravel(),yerr=np.abs([v24_lerr_27GeV_Trajectum.ravel(),v24_uerr_27GeV_Trajectum.ravel()]), capsize=5,fmt="o",color="green",label="Trajectum, 27 GeV")

# plt.errorbar(centrality_bins_19GeV,v24_vals_19GeV,yerr=v24_errors_19GeV, capsize=5,fmt="^",color="purple",label="STAR data (arXiv:2201.10365), 19.6 GeV")
# plt.errorbar(centrality.ravel(),v24_vals_19GeV_Trajectum.ravel(),yerr=np.abs([v24_lerr_19GeV_Trajectum.ravel(),v24_uerr_19GeV_Trajectum.ravel()]), capsize=5,fmt="o",color="purple",label="Trajectum, 19.6 GeV")

plt.axvline(x=min(centrality_bins_200GeV),linestyle="--",label="Most central bin from 200 GeV data",color="blue")
plt.axvline(x=min(centrality_bins_54GeV),linestyle="--",label="Most central bin from 54.4 GeV data",color="red")
# plt.axvline(x=min(centrality_bins_27GeV),linestyle="--",label="Most central bin from 27 GeV data",color="green")
# plt.axvline(x=min(centrality_bins_19GeV),linestyle="--",label="Most central bin from 19.6 GeV data",color="purple")

plt.xlabel("Centrality (%)")
plt.ylabel("$v_2\{4\}$")
plt.xlim([0,67.5])
plt.ylim([0,0.07])
plt.legend(prop={'size': '8'},loc="lower right")
plt.grid()
plt.title("$\sqrt{s_{NN}}$-Evolution of $v_2\{4\}$")
# Out:
# <>:23: SyntaxWarning: invalid escape sequence '\{'
# <>:28: SyntaxWarning: invalid escape sequence '\s'
# <>:23: SyntaxWarning: invalid escape sequence '\{'
# <>:28: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/mb/30yyqfg516jdbq01t3whp1r40000gn/T/ipykernel_2418/3686586664.py:23: SyntaxWarning: invalid escape sequence '\{'
#   plt.ylabel("$v_2\{4\}$")
# /var/folders/mb/30yyqfg516jdbq01t3whp1r40000gn/T/ipykernel_2418/3686586664.py:28: SyntaxWarning: invalid escape sequence '\s'
#   plt.title("$\sqrt{s_{NN}}$-Evolution of $v_2\{4\}$")
# Text(0.5, 1.0, '$\\sqrt{s_{NN}}$-Evolution of $v_2\\{4\\}$')
