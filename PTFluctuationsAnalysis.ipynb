# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
filepath_200GeV = "/Users/christianschmidt/Desktop/trajectum-2.1/src/200GeV_FinalResult1_NoSmash_80000_500PJ.h5"  
filepath_Midptthreshold = "/Users/christianschmidt/Desktop/trajectum-2.1/src/PT_THRESHOLD_STUDY_200GeV_80000_160PJ.h5"
filepath_Midmidptthreshold = "/Users/christianschmidt/Desktop/trajectum-2.1/src/PT_THRESHOLD_STUDY1_200GeV_80000_160PJ.h5"
filepath_Highptthreshold = "/Users/christianschmidt/Desktop/trajectum-2.1/src/200GeV_HIGHPTCUTS_80000_200PJ.h5"  
# filepath_200GeV = "/Users/christianschmidt/Desktop/trajectum-2.1/src/200GeV_LowStats_Smash_5000_50PJ.h5"

# %%
#Directories, 1000 MeV pT threshold
multiplicitycharged_THRESHOLD1000MeV_vals_dir = "multiplicitycharged/STARTPC1000MeV/centralitybinned/values"
multiplicitycharged_THRESHOLD1000MeV_uerrs_dir = "multiplicitycharged/STARTPC1000MeV/centralitybinned/uppererrors"
multiplicitycharged_THRESHOLD1000MeV_lerrs_dir = "multiplicitycharged/STARTPC1000MeV/centralitybinned/lowererrors"

pTfluctuationschargedk2_THRESHOLD1000MeV_vals_dir = "ptfluctuationschargedk2/STARTPC1000MeV/centralitybinned/values"
pTfluctuationschargedk2_THRESHOLD1000MeV_uerrs_dir = "ptfluctuationschargedk2/STARTPC1000MeV/centralitybinned/uppererrors"
pTfluctuationschargedk2_THRESHOLD1000MeV_lerrs_dir = "ptfluctuationschargedk2/STARTPC1000MeV/centralitybinned/lowererrors"

pTfluctuationschargedk3_THRESHOLD1000MeV_vals_dir = "ptfluctuationschargedk3/STARTPC1000MeV/centralitybinned/values"
pTfluctuationschargedk3_THRESHOLD1000MeV_uerrs_dir = "ptfluctuationschargedk3/STARTPC1000MeV/centralitybinned/uppererrors"
pTfluctuationschargedk3_THRESHOLD1000MeV_lerrs_dir = "ptfluctuationschargedk3/STARTPC1000MeV/centralitybinned/lowererrors"

timedependentaveragetemperature_THRESHOLD1000MeV_vals_dir = "timedependentaveragetemperature/STARTPC1000MeV/centralitybinned/values"
timedependentaveragetemperature_THRESHOLD1000MeV_uerrs_dir = "timedependentaveragetemperature/STARTPC1000MeV/centralitybinned/uppererrors"
timedependentaveragetemperature_THRESHOLD1000MeV_lerrs_dir = "timedependentaveragetemperature/STARTPC1000MeV/centralitybinned/lowererrors"

timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_vals_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC1000MeV/centralitybinned/values"
timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_uerrs_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC1000MeV/centralitybinned/uppererrors"
timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_lerrs_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC1000MeV/centralitybinned/lowererrors"

with h5py.File(filepath_Highptthreshold, "r") as hdf:
    multiplicitycharged_THRESHOLD1000MeV_vals = hdf[multiplicitycharged_THRESHOLD1000MeV_vals_dir][:]
    multiplicitycharged_THRESHOLD1000MeV_uerrs = hdf[multiplicitycharged_THRESHOLD1000MeV_uerrs_dir][:]
    multiplicitycharged_THRESHOLD1000MeV_lerrs = hdf[multiplicitycharged_THRESHOLD1000MeV_lerrs_dir][:]
    multiplicitycharged_THRESHOLD1000MeV_symerrs = 0.5*(multiplicitycharged_THRESHOLD1000MeV_lerrs+multiplicitycharged_THRESHOLD1000MeV_uerrs)
    
    pTfluctuationschargedk2_THRESHOLD1000MeV_vals = hdf[pTfluctuationschargedk2_THRESHOLD1000MeV_vals_dir][:]
    pTfluctuationschargedk2_THRESHOLD1000MeV_uerrs = hdf[pTfluctuationschargedk2_THRESHOLD1000MeV_uerrs_dir][:]
    pTfluctuationschargedk2_THRESHOLD1000MeV_lerrs = hdf[pTfluctuationschargedk2_THRESHOLD1000MeV_lerrs_dir][:]

    pTfluctuationschargedk3_THRESHOLD1000MeV_vals = hdf[pTfluctuationschargedk3_THRESHOLD1000MeV_vals_dir][:]
    pTfluctuationschargedk3_THRESHOLD1000MeV_uerrs = hdf[pTfluctuationschargedk3_THRESHOLD1000MeV_uerrs_dir][:]
    pTfluctuationschargedk3_THRESHOLD1000MeV_lerrs = hdf[pTfluctuationschargedk3_THRESHOLD1000MeV_lerrs_dir][:]

    timedependentaveragetemperature_THRESHOLD1000MeV_vals = hdf[timedependentaveragetemperature_THRESHOLD1000MeV_vals_dir][:]
    timedependentaveragetemperature_THRESHOLD1000MeV_uerrs = hdf[timedependentaveragetemperature_THRESHOLD1000MeV_uerrs_dir][:]
    timedependentaveragetemperature_THRESHOLD1000MeV_lerrs = hdf[timedependentaveragetemperature_THRESHOLD1000MeV_lerrs_dir][:]

    timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_vals = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_vals_dir][:]
    timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_uerrs = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_uerrs_dir][:]
    timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_lerrs = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_lerrs_dir][:]

# %%
#Directories, 800 MeV pT threshold
multiplicitycharged_THRESHOLD800MeV_vals_dir = "multiplicitycharged/STARTPC800MeV/centralitybinned/values"
multiplicitycharged_THRESHOLD800MeV_uerrs_dir = "multiplicitycharged/STARTPC800MeV/centralitybinned/uppererrors"
multiplicitycharged_THRESHOLD800MeV_lerrs_dir = "multiplicitycharged/STARTPC800MeV/centralitybinned/lowererrors"

pTfluctuationschargedk2_THRESHOLD800MeV_vals_dir = "ptfluctuationschargedk2/STARTPC800MeV/centralitybinned/values"
pTfluctuationschargedk2_THRESHOLD800MeV_uerrs_dir = "ptfluctuationschargedk2/STARTPC800MeV/centralitybinned/uppererrors"
pTfluctuationschargedk2_THRESHOLD800MeV_lerrs_dir = "ptfluctuationschargedk2/STARTPC800MeV/centralitybinned/lowererrors"

pTfluctuationschargedk3_THRESHOLD800MeV_vals_dir = "ptfluctuationschargedk3/STARTPC800MeV/centralitybinned/values"
pTfluctuationschargedk3_THRESHOLD800MeV_uerrs_dir = "ptfluctuationschargedk3/STARTPC800MeV/centralitybinned/uppererrors"
pTfluctuationschargedk3_THRESHOLD800MeV_lerrs_dir = "ptfluctuationschargedk3/STARTPC800MeV/centralitybinned/lowererrors"

timedependentaveragetemperature_THRESHOLD800MeV_vals_dir = "timedependentaveragetemperature/STARTPC800MeV/centralitybinned/values"
timedependentaveragetemperature_THRESHOLD800MeV_uerrs_dir = "timedependentaveragetemperature/STARTPC800MeV/centralitybinned/uppererrors"
timedependentaveragetemperature_THRESHOLD800MeV_lerrs_dir = "timedependentaveragetemperature/STARTPC800MeV/centralitybinned/lowererrors"

timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_vals_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC800MeV/centralitybinned/values"
timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_uerrs_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC800MeV/centralitybinned/uppererrors"
timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_lerrs_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC800MeV/centralitybinned/lowererrors"

with h5py.File(filepath_Midptthreshold, "r") as hdf:
    multiplicitycharged_THRESHOLD800MeV_vals = hdf[multiplicitycharged_THRESHOLD800MeV_vals_dir][:]
    multiplicitycharged_THRESHOLD800MeV_uerrs = hdf[multiplicitycharged_THRESHOLD800MeV_uerrs_dir][:]
    multiplicitycharged_THRESHOLD800MeV_lerrs = hdf[multiplicitycharged_THRESHOLD800MeV_lerrs_dir][:]
    multiplicitycharged_THRESHOLD800MeV_symerrs = 0.5*(multiplicitycharged_THRESHOLD800MeV_lerrs+multiplicitycharged_THRESHOLD800MeV_uerrs)
    
    pTfluctuationschargedk2_THRESHOLD800MeV_vals = hdf[pTfluctuationschargedk2_THRESHOLD800MeV_vals_dir][:]
    pTfluctuationschargedk2_THRESHOLD800MeV_uerrs = hdf[pTfluctuationschargedk2_THRESHOLD800MeV_uerrs_dir][:]
    pTfluctuationschargedk2_THRESHOLD800MeV_lerrs = hdf[pTfluctuationschargedk2_THRESHOLD800MeV_lerrs_dir][:]

    pTfluctuationschargedk3_THRESHOLD800MeV_vals = hdf[pTfluctuationschargedk3_THRESHOLD800MeV_vals_dir][:]
    pTfluctuationschargedk3_THRESHOLD800MeV_uerrs = hdf[pTfluctuationschargedk3_THRESHOLD800MeV_uerrs_dir][:]
    pTfluctuationschargedk3_THRESHOLD800MeV_lerrs = hdf[pTfluctuationschargedk3_THRESHOLD800MeV_lerrs_dir][:]

    timedependentaveragetemperature_THRESHOLD800MeV_vals = hdf[timedependentaveragetemperature_THRESHOLD800MeV_vals_dir][:]
    timedependentaveragetemperature_THRESHOLD800MeV_uerrs = hdf[timedependentaveragetemperature_THRESHOLD800MeV_uerrs_dir][:]
    timedependentaveragetemperature_THRESHOLD800MeV_lerrs = hdf[timedependentaveragetemperature_THRESHOLD800MeV_lerrs_dir][:]

    timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_vals = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_vals_dir][:]
    timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_uerrs = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_uerrs_dir][:]
    timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_lerrs = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_lerrs_dir][:]

# %%
#Directories, 600 MeV pT threshold
multiplicitycharged_THRESHOLD600MeV_vals_dir = "multiplicitycharged/STARTPC600MeV/centralitybinned/values"
multiplicitycharged_THRESHOLD600MeV_uerrs_dir = "multiplicitycharged/STARTPC600MeV/centralitybinned/uppererrors"
multiplicitycharged_THRESHOLD600MeV_lerrs_dir = "multiplicitycharged/STARTPC600MeV/centralitybinned/lowererrors"

pTfluctuationschargedk2_THRESHOLD600MeV_vals_dir = "ptfluctuationschargedk2/STARTPC600MeV/centralitybinned/values"
pTfluctuationschargedk2_THRESHOLD600MeV_uerrs_dir = "ptfluctuationschargedk2/STARTPC600MeV/centralitybinned/uppererrors"
pTfluctuationschargedk2_THRESHOLD600MeV_lerrs_dir = "ptfluctuationschargedk2/STARTPC600MeV/centralitybinned/lowererrors"

pTfluctuationschargedk3_THRESHOLD600MeV_vals_dir = "ptfluctuationschargedk3/STARTPC600MeV/centralitybinned/values"
pTfluctuationschargedk3_THRESHOLD600MeV_uerrs_dir = "ptfluctuationschargedk3/STARTPC600MeV/centralitybinned/uppererrors"
pTfluctuationschargedk3_THRESHOLD600MeV_lerrs_dir = "ptfluctuationschargedk3/STARTPC600MeV/centralitybinned/lowererrors"

timedependentaveragetemperature_THRESHOLD600MeV_vals_dir = "timedependentaveragetemperature/STARTPC600MeV/centralitybinned/values"
timedependentaveragetemperature_THRESHOLD600MeV_uerrs_dir = "timedependentaveragetemperature/STARTPC600MeV/centralitybinned/uppererrors"
timedependentaveragetemperature_THRESHOLD600MeV_lerrs_dir = "timedependentaveragetemperature/STARTPC600MeV/centralitybinned/lowererrors"

timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_vals_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC600MeV/centralitybinned/values"
timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_uerrs_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC600MeV/centralitybinned/uppererrors"
timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_lerrs_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC600MeV/centralitybinned/lowererrors"

with h5py.File(filepath_Midptthreshold, "r") as hdf:
    multiplicitycharged_THRESHOLD600MeV_vals = hdf[multiplicitycharged_THRESHOLD600MeV_vals_dir][:]
    multiplicitycharged_THRESHOLD600MeV_uerrs = hdf[multiplicitycharged_THRESHOLD600MeV_uerrs_dir][:]
    multiplicitycharged_THRESHOLD600MeV_lerrs = hdf[multiplicitycharged_THRESHOLD600MeV_lerrs_dir][:]
    multiplicitycharged_THRESHOLD600MeV_symerrs = 0.5*(multiplicitycharged_THRESHOLD600MeV_lerrs+multiplicitycharged_THRESHOLD600MeV_uerrs)
    
    pTfluctuationschargedk2_THRESHOLD600MeV_vals = hdf[pTfluctuationschargedk2_THRESHOLD600MeV_vals_dir][:]
    pTfluctuationschargedk2_THRESHOLD600MeV_uerrs = hdf[pTfluctuationschargedk2_THRESHOLD600MeV_uerrs_dir][:]
    pTfluctuationschargedk2_THRESHOLD600MeV_lerrs = hdf[pTfluctuationschargedk2_THRESHOLD600MeV_lerrs_dir][:]

    pTfluctuationschargedk3_THRESHOLD600MeV_vals = hdf[pTfluctuationschargedk3_THRESHOLD600MeV_vals_dir][:]
    pTfluctuationschargedk3_THRESHOLD600MeV_uerrs = hdf[pTfluctuationschargedk3_THRESHOLD600MeV_uerrs_dir][:]
    pTfluctuationschargedk3_THRESHOLD600MeV_lerrs = hdf[pTfluctuationschargedk3_THRESHOLD600MeV_lerrs_dir][:]

    timedependentaveragetemperature_THRESHOLD600MeV_vals = hdf[timedependentaveragetemperature_THRESHOLD600MeV_vals_dir][:]
    timedependentaveragetemperature_THRESHOLD600MeV_uerrs = hdf[timedependentaveragetemperature_THRESHOLD600MeV_uerrs_dir][:]
    timedependentaveragetemperature_THRESHOLD600MeV_lerrs = hdf[timedependentaveragetemperature_THRESHOLD600MeV_lerrs_dir][:]

    timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_vals = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_vals_dir][:]
    timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_uerrs = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_uerrs_dir][:]
    timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_lerrs = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_lerrs_dir][:]

# %%
# Directories, 550 MeV pT threshold
multiplicitycharged_THRESHOLD550MeV_vals_dir = "multiplicitycharged/STARTPC550MeV/centralitybinned/values"
multiplicitycharged_THRESHOLD550MeV_uerrs_dir = "multiplicitycharged/STARTPC550MeV/centralitybinned/uppererrors"
multiplicitycharged_THRESHOLD550MeV_lerrs_dir = "multiplicitycharged/STARTPC550MeV/centralitybinned/lowererrors"

pTfluctuationschargedk2_THRESHOLD550MeV_vals_dir = "ptfluctuationschargedk2/STARTPC550MeV/centralitybinned/values"
pTfluctuationschargedk2_THRESHOLD550MeV_uerrs_dir = "ptfluctuationschargedk2/STARTPC550MeV/centralitybinned/uppererrors"
pTfluctuationschargedk2_THRESHOLD550MeV_lerrs_dir = "ptfluctuationschargedk2/STARTPC550MeV/centralitybinned/lowererrors"

pTfluctuationschargedk3_THRESHOLD550MeV_vals_dir = "ptfluctuationschargedk3/STARTPC550MeV/centralitybinned/values"
pTfluctuationschargedk3_THRESHOLD550MeV_uerrs_dir = "ptfluctuationschargedk3/STARTPC550MeV/centralitybinned/uppererrors"
pTfluctuationschargedk3_THRESHOLD550MeV_lerrs_dir = "ptfluctuationschargedk3/STARTPC550MeV/centralitybinned/lowererrors"

timedependentaveragetemperature_THRESHOLD550MeV_vals_dir = "timedependentaveragetemperature/STARTPC550MeV/centralitybinned/values"
timedependentaveragetemperature_THRESHOLD550MeV_uerrs_dir = "timedependentaveragetemperature/STARTPC550MeV/centralitybinned/uppererrors"
timedependentaveragetemperature_THRESHOLD550MeV_lerrs_dir = "timedependentaveragetemperature/STARTPC550MeV/centralitybinned/lowererrors"

timedependentaveragetemperaturestandarddeviation_THRESHOLD550MeV_vals_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC550MeV/centralitybinned/values"
timedependentaveragetemperaturestandarddeviation_THRESHOLD550MeV_uerrs_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC550MeV/centralitybinned/uppererrors"
timedependentaveragetemperaturestandarddeviation_THRESHOLD550MeV_lerrs_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC550MeV/centralitybinned/lowererrors"

with h5py.File(filepath_Midmidptthreshold, "r") as hdf:
    multiplicitycharged_THRESHOLD550MeV_vals = hdf[multiplicitycharged_THRESHOLD550MeV_vals_dir][:]
    multiplicitycharged_THRESHOLD550MeV_uerrs = hdf[multiplicitycharged_THRESHOLD550MeV_uerrs_dir][:]
    multiplicitycharged_THRESHOLD550MeV_lerrs = hdf[multiplicitycharged_THRESHOLD550MeV_lerrs_dir][:]
    multiplicitycharged_THRESHOLD550MeV_symerrs = 0.5*(multiplicitycharged_THRESHOLD550MeV_lerrs+multiplicitycharged_THRESHOLD550MeV_uerrs)

    pTfluctuationschargedk2_THRESHOLD550MeV_vals = hdf[pTfluctuationschargedk2_THRESHOLD550MeV_vals_dir][:]
    pTfluctuationschargedk2_THRESHOLD550MeV_uerrs = hdf[pTfluctuationschargedk2_THRESHOLD550MeV_uerrs_dir][:]
    pTfluctuationschargedk2_THRESHOLD550MeV_lerrs = hdf[pTfluctuationschargedk2_THRESHOLD550MeV_lerrs_dir][:]

    pTfluctuationschargedk3_THRESHOLD550MeV_vals = hdf[pTfluctuationschargedk3_THRESHOLD550MeV_vals_dir][:]
    pTfluctuationschargedk3_THRESHOLD550MeV_uerrs = hdf[pTfluctuationschargedk3_THRESHOLD550MeV_uerrs_dir][:]
    pTfluctuationschargedk3_THRESHOLD550MeV_lerrs = hdf[pTfluctuationschargedk3_THRESHOLD550MeV_lerrs_dir][:]

    timedependentaveragetemperature_THRESHOLD550MeV_vals = hdf[timedependentaveragetemperature_THRESHOLD550MeV_vals_dir][:]
    timedependentaveragetemperature_THRESHOLD550MeV_uerrs = hdf[timedependentaveragetemperature_THRESHOLD550MeV_uerrs_dir][:]
    timedependentaveragetemperature_THRESHOLD550MeV_lerrs = hdf[timedependentaveragetemperature_THRESHOLD550MeV_lerrs_dir][:]

    timedependentaveragetemperaturestandarddeviation_THRESHOLD550MeV_vals = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD550MeV_vals_dir][:]
    timedependentaveragetemperaturestandarddeviation_THRESHOLD550MeV_uerrs = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD550MeV_uerrs_dir][:]
    timedependentaveragetemperaturestandarddeviation_THRESHOLD550MeV_lerrs = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD550MeV_lerrs_dir][:]

# %%
# Directories, 500 MeV pT threshold
multiplicitycharged_THRESHOLD500MeV_vals_dir = "multiplicitycharged/STARTPC500MeV/centralitybinned/values"
multiplicitycharged_THRESHOLD500MeV_uerrs_dir = "multiplicitycharged/STARTPC500MeV/centralitybinned/uppererrors"
multiplicitycharged_THRESHOLD500MeV_lerrs_dir = "multiplicitycharged/STARTPC500MeV/centralitybinned/lowererrors"

pTfluctuationschargedk2_THRESHOLD500MeV_vals_dir = "ptfluctuationschargedk2/STARTPC500MeV/centralitybinned/values"
pTfluctuationschargedk2_THRESHOLD500MeV_uerrs_dir = "ptfluctuationschargedk2/STARTPC500MeV/centralitybinned/uppererrors"
pTfluctuationschargedk2_THRESHOLD500MeV_lerrs_dir = "ptfluctuationschargedk2/STARTPC500MeV/centralitybinned/lowererrors"

pTfluctuationschargedk3_THRESHOLD500MeV_vals_dir = "ptfluctuationschargedk3/STARTPC500MeV/centralitybinned/values"
pTfluctuationschargedk3_THRESHOLD500MeV_uerrs_dir = "ptfluctuationschargedk3/STARTPC500MeV/centralitybinned/uppererrors"
pTfluctuationschargedk3_THRESHOLD500MeV_lerrs_dir = "ptfluctuationschargedk3/STARTPC500MeV/centralitybinned/lowererrors"

timedependentaveragetemperature_THRESHOLD500MeV_vals_dir = "timedependentaveragetemperature/STARTPC500MeV/centralitybinned/values"
timedependentaveragetemperature_THRESHOLD500MeV_uerrs_dir = "timedependentaveragetemperature/STARTPC500MeV/centralitybinned/uppererrors"
timedependentaveragetemperature_THRESHOLD500MeV_lerrs_dir = "timedependentaveragetemperature/STARTPC500MeV/centralitybinned/lowererrors"

timedependentaveragetemperaturestandarddeviation_THRESHOLD500MeV_vals_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC500MeV/centralitybinned/values"
timedependentaveragetemperaturestandarddeviation_THRESHOLD500MeV_uerrs_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC500MeV/centralitybinned/uppererrors"
timedependentaveragetemperaturestandarddeviation_THRESHOLD500MeV_lerrs_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC500MeV/centralitybinned/lowererrors"

with h5py.File(filepath_Midmidptthreshold, "r") as hdf:
    multiplicitycharged_THRESHOLD500MeV_vals = hdf[multiplicitycharged_THRESHOLD500MeV_vals_dir][:]
    multiplicitycharged_THRESHOLD500MeV_uerrs = hdf[multiplicitycharged_THRESHOLD500MeV_uerrs_dir][:]
    multiplicitycharged_THRESHOLD500MeV_lerrs = hdf[multiplicitycharged_THRESHOLD500MeV_lerrs_dir][:]
    multiplicitycharged_THRESHOLD500MeV_symerrs = 0.5*(multiplicitycharged_THRESHOLD500MeV_lerrs+multiplicitycharged_THRESHOLD500MeV_uerrs)

    pTfluctuationschargedk2_THRESHOLD500MeV_vals = hdf[pTfluctuationschargedk2_THRESHOLD500MeV_vals_dir][:]
    pTfluctuationschargedk2_THRESHOLD500MeV_uerrs = hdf[pTfluctuationschargedk2_THRESHOLD500MeV_uerrs_dir][:]
    pTfluctuationschargedk2_THRESHOLD500MeV_lerrs = hdf[pTfluctuationschargedk2_THRESHOLD500MeV_lerrs_dir][:]

    pTfluctuationschargedk3_THRESHOLD500MeV_vals = hdf[pTfluctuationschargedk3_THRESHOLD500MeV_vals_dir][:]
    pTfluctuationschargedk3_THRESHOLD500MeV_uerrs = hdf[pTfluctuationschargedk3_THRESHOLD500MeV_uerrs_dir][:]
    pTfluctuationschargedk3_THRESHOLD500MeV_lerrs = hdf[pTfluctuationschargedk3_THRESHOLD500MeV_lerrs_dir][:]

    timedependentaveragetemperature_THRESHOLD500MeV_vals = hdf[timedependentaveragetemperature_THRESHOLD500MeV_vals_dir][:]
    timedependentaveragetemperature_THRESHOLD500MeV_uerrs = hdf[timedependentaveragetemperature_THRESHOLD500MeV_uerrs_dir][:]
    timedependentaveragetemperature_THRESHOLD500MeV_lerrs = hdf[timedependentaveragetemperature_THRESHOLD500MeV_lerrs_dir][:]

    timedependentaveragetemperaturestandarddeviation_THRESHOLD500MeV_vals = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD500MeV_vals_dir][:]
    timedependentaveragetemperaturestandarddeviation_THRESHOLD500MeV_uerrs = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD500MeV_uerrs_dir][:]
    timedependentaveragetemperaturestandarddeviation_THRESHOLD500MeV_lerrs = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD500MeV_lerrs_dir][:]

# %%
#Directories, 450 MeV pT threshold
multiplicitycharged_THRESHOLD450MeV_vals_dir = "multiplicitycharged/STARTPC450MeV/centralitybinned/values"
multiplicitycharged_THRESHOLD450MeV_uerrs_dir = "multiplicitycharged/STARTPC450MeV/centralitybinned/uppererrors"
multiplicitycharged_THRESHOLD450MeV_lerrs_dir = "multiplicitycharged/STARTPC450MeV/centralitybinned/lowererrors"

pTfluctuationschargedk2_THRESHOLD450MeV_vals_dir = "ptfluctuationschargedk2/STARTPC450MeV/centralitybinned/values"
pTfluctuationschargedk2_THRESHOLD450MeV_uerrs_dir = "ptfluctuationschargedk2/STARTPC450MeV/centralitybinned/uppererrors"
pTfluctuationschargedk2_THRESHOLD450MeV_lerrs_dir = "ptfluctuationschargedk2/STARTPC450MeV/centralitybinned/lowererrors"

pTfluctuationschargedk3_THRESHOLD450MeV_vals_dir = "ptfluctuationschargedk3/STARTPC450MeV/centralitybinned/values"
pTfluctuationschargedk3_THRESHOLD450MeV_uerrs_dir = "ptfluctuationschargedk3/STARTPC450MeV/centralitybinned/uppererrors"
pTfluctuationschargedk3_THRESHOLD450MeV_lerrs_dir = "ptfluctuationschargedk3/STARTPC450MeV/centralitybinned/lowererrors"

timedependentaveragetemperature_THRESHOLD450MeV_vals_dir = "timedependentaveragetemperature/STARTPC450MeV/centralitybinned/values"
timedependentaveragetemperature_THRESHOLD450MeV_uerrs_dir = "timedependentaveragetemperature/STARTPC450MeV/centralitybinned/uppererrors"
timedependentaveragetemperature_THRESHOLD450MeV_lerrs_dir = "timedependentaveragetemperature/STARTPC450MeV/centralitybinned/lowererrors"

timedependentaveragetemperaturestandarddeviation_THRESHOLD450MeV_vals_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC450MeV/centralitybinned/values"
timedependentaveragetemperaturestandarddeviation_THRESHOLD450MeV_uerrs_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC450MeV/centralitybinned/uppererrors"
timedependentaveragetemperaturestandarddeviation_THRESHOLD450MeV_lerrs_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC450MeV/centralitybinned/lowererrors"

with h5py.File(filepath_Midmidptthreshold, "r") as hdf:
    # multiplicitychargedpio_27GeV_vals = hdf[multiplicitychargedpions_vals_dir][:]
    multiplicitycharged_THRESHOLD450MeV_vals = hdf[multiplicitycharged_THRESHOLD450MeV_vals_dir][:]
    multiplicitycharged_THRESHOLD450MeV_uerrs = hdf[multiplicitycharged_THRESHOLD450MeV_uerrs_dir][:]
    multiplicitycharged_THRESHOLD450MeV_lerrs = hdf[multiplicitycharged_THRESHOLD450MeV_lerrs_dir][:]
    multiplicitycharged_THRESHOLD450MeV_symerrs = 0.5*(multiplicitycharged_THRESHOLD450MeV_lerrs+multiplicitycharged_THRESHOLD450MeV_uerrs)
    
    pTfluctuationschargedk2_THRESHOLD450MeV_vals = hdf[pTfluctuationschargedk2_THRESHOLD450MeV_vals_dir][:]
    pTfluctuationschargedk2_THRESHOLD450MeV_uerrs = hdf[pTfluctuationschargedk2_THRESHOLD450MeV_uerrs_dir][:]
    pTfluctuationschargedk2_THRESHOLD450MeV_lerrs = hdf[pTfluctuationschargedk2_THRESHOLD450MeV_lerrs_dir][:]

    pTfluctuationschargedk3_THRESHOLD450MeV_vals = hdf[pTfluctuationschargedk3_THRESHOLD450MeV_vals_dir][:]
    pTfluctuationschargedk3_THRESHOLD450MeV_uerrs = hdf[pTfluctuationschargedk3_THRESHOLD450MeV_uerrs_dir][:]
    pTfluctuationschargedk3_THRESHOLD450MeV_lerrs = hdf[pTfluctuationschargedk3_THRESHOLD450MeV_lerrs_dir][:]

    timedependentaveragetemperature_THRESHOLD450MeV_vals = hdf[timedependentaveragetemperature_THRESHOLD450MeV_vals_dir][:]
    timedependentaveragetemperature_THRESHOLD450MeV_uerrs = hdf[timedependentaveragetemperature_THRESHOLD450MeV_uerrs_dir][:]
    timedependentaveragetemperature_THRESHOLD450MeV_lerrs = hdf[timedependentaveragetemperature_THRESHOLD450MeV_lerrs_dir][:]

    timedependentaveragetemperaturestandarddeviation_THRESHOLD450MeV_vals = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD450MeV_vals_dir][:]
    timedependentaveragetemperaturestandarddeviation_THRESHOLD450MeV_uerrs = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD450MeV_uerrs_dir][:]
    timedependentaveragetemperaturestandarddeviation_THRESHOLD450MeV_lerrs = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD450MeV_lerrs_dir][:]

# %%
#Directories, 400 MeV pT threshold
multiplicitycharged_THRESHOLD400MeV_vals_dir = "multiplicitycharged/STARTPC2/centralitybinned/values"
multiplicitycharged_THRESHOLD400MeV_uerrs_dir = "multiplicitycharged/STARTPC2/centralitybinned/uppererrors"
multiplicitycharged_THRESHOLD400MeV_lerrs_dir = "multiplicitycharged/STARTPC2/centralitybinned/lowererrors"

pTfluctuationschargedk2_THRESHOLD400MeV_vals_dir = "ptfluctuationschargedk2/STARTPC2/centralitybinned/values"
pTfluctuationschargedk2_THRESHOLD400MeV_uerrs_dir = "ptfluctuationschargedk2/STARTPC2/centralitybinned/uppererrors"
pTfluctuationschargedk2_THRESHOLD400MeV_lerrs_dir = "ptfluctuationschargedk2/STARTPC2/centralitybinned/lowererrors"

pTfluctuationschargedk3_THRESHOLD400MeV_vals_dir = "ptfluctuationschargedk3/STARTPC2/centralitybinned/values"
pTfluctuationschargedk3_THRESHOLD400MeV_uerrs_dir = "ptfluctuationschargedk3/STARTPC2/centralitybinned/uppererrors"
pTfluctuationschargedk3_THRESHOLD400MeV_lerrs_dir = "ptfluctuationschargedk3/STARTPC2/centralitybinned/lowererrors"

timedependentaveragetemperature_THRESHOLD400MeV_vals_dir = "timedependentaveragetemperature/STARTPC2/centralitybinned/values"
timedependentaveragetemperature_THRESHOLD400MeV_uerrs_dir = "timedependentaveragetemperature/STARTPC2/centralitybinned/uppererrors"
timedependentaveragetemperature_THRESHOLD400MeV_lerrs_dir = "timedependentaveragetemperature/STARTPC2/centralitybinned/lowererrors"

timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_vals_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC2/centralitybinned/values"
timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_uerrs_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC2/centralitybinned/uppererrors"
timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_lerrs_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC2/centralitybinned/lowererrors"

with h5py.File(filepath_200GeV, "r") as hdf:
    # multiplicitychargedpio_27GeV_vals = hdf[multiplicitychargedpions_vals_dir][:]
    multiplicitycharged_THRESHOLD400MeV_vals = hdf[multiplicitycharged_THRESHOLD400MeV_vals_dir][:]
    multiplicitycharged_THRESHOLD400MeV_uerrs = hdf[multiplicitycharged_THRESHOLD400MeV_uerrs_dir][:]
    multiplicitycharged_THRESHOLD400MeV_lerrs = hdf[multiplicitycharged_THRESHOLD400MeV_lerrs_dir][:]
    multiplicitycharged_THRESHOLD400MeV_symerrs = 0.5*(multiplicitycharged_THRESHOLD400MeV_lerrs+multiplicitycharged_THRESHOLD400MeV_uerrs)
    
    pTfluctuationschargedk2_THRESHOLD400MeV_vals = hdf[pTfluctuationschargedk2_THRESHOLD400MeV_vals_dir][:]
    pTfluctuationschargedk2_THRESHOLD400MeV_uerrs = hdf[pTfluctuationschargedk2_THRESHOLD400MeV_uerrs_dir][:]
    pTfluctuationschargedk2_THRESHOLD400MeV_lerrs = hdf[pTfluctuationschargedk2_THRESHOLD400MeV_lerrs_dir][:]

    pTfluctuationschargedk3_THRESHOLD400MeV_vals = hdf[pTfluctuationschargedk3_THRESHOLD400MeV_vals_dir][:]
    pTfluctuationschargedk3_THRESHOLD400MeV_uerrs = hdf[pTfluctuationschargedk3_THRESHOLD400MeV_uerrs_dir][:]
    pTfluctuationschargedk3_THRESHOLD400MeV_lerrs = hdf[pTfluctuationschargedk3_THRESHOLD400MeV_lerrs_dir][:]

    timedependentaveragetemperature_THRESHOLD400MeV_vals = hdf[timedependentaveragetemperature_THRESHOLD400MeV_vals_dir][:]
    timedependentaveragetemperature_THRESHOLD400MeV_uerrs = hdf[timedependentaveragetemperature_THRESHOLD400MeV_uerrs_dir][:]
    timedependentaveragetemperature_THRESHOLD400MeV_lerrs = hdf[timedependentaveragetemperature_THRESHOLD400MeV_lerrs_dir][:]

    timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_vals = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_vals_dir][:]
    timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_uerrs = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_uerrs_dir][:]
    timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_lerrs = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_lerrs_dir][:]

# %%
#Directories, 200 MeV pT threshold
multiplicitycharged_THRESHOLD200MeV_vals_dir = "multiplicitycharged/STARTPC/centralitybinned/values"
multiplicitycharged_THRESHOLD200MeV_uerrs_dir = "multiplicitycharged/STARTPC/centralitybinned/uppererrors"
multiplicitycharged_THRESHOLD200MeV_lerrs_dir = "multiplicitycharged/STARTPC/centralitybinned/lowererrors"

pTfluctuationschargedk2_THRESHOLD200MeV_vals_dir = "ptfluctuationschargedk2/STARTPC/centralitybinned/values"
pTfluctuationschargedk2_THRESHOLD200MeV_uerrs_dir = "ptfluctuationschargedk2/STARTPC/centralitybinned/uppererrors"
pTfluctuationschargedk2_THRESHOLD200MeV_lerrs_dir = "ptfluctuationschargedk2/STARTPC/centralitybinned/lowererrors"

pTfluctuationschargedk3_THRESHOLD200MeV_vals_dir = "ptfluctuationschargedk3/STARTPC/centralitybinned/values"
pTfluctuationschargedk3_THRESHOLD200MeV_uerrs_dir = "ptfluctuationschargedk3/STARTPC/centralitybinned/uppererrors"
pTfluctuationschargedk3_THRESHOLD200MeV_lerrs_dir = "ptfluctuationschargedk3/STARTPC/centralitybinned/lowererrors"

timedependentaveragetemperature_THRESHOLD200MeV_vals_dir = "timedependentaveragetemperature/STARTPC/centralitybinned/values"
timedependentaveragetemperature_THRESHOLD200MeV_uerrs_dir = "timedependentaveragetemperature/STARTPC/centralitybinned/uppererrors"
timedependentaveragetemperature_THRESHOLD200MeV_lerrs_dir = "timedependentaveragetemperature/STARTPC/centralitybinned/lowererrors"

timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_vals_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC/centralitybinned/values"
timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_uerrs_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC/centralitybinned/uppererrors"
timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_lerrs_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC/centralitybinned/lowererrors"

tau_vals_dir = "timedependentaveragetemperaturestandarddeviation/STARTPC/centralitybinned/independentvariable"

with h5py.File(filepath_200GeV, "r") as hdf:
    # multiplicitychargedpio_27GeV_vals = hdf[multiplicitychargedpions_vals_dir][:]
    multiplicitycharged_THRESHOLD200MeV_vals = hdf[multiplicitycharged_THRESHOLD200MeV_vals_dir][:]
    multiplicitycharged_THRESHOLD200MeV_uerrs = hdf[multiplicitycharged_THRESHOLD200MeV_uerrs_dir][:]
    multiplicitycharged_THRESHOLD200MeV_lerrs = hdf[multiplicitycharged_THRESHOLD200MeV_lerrs_dir][:]
    multiplicitycharged_THRESHOLD200MeV_symerrs = 0.5*(multiplicitycharged_THRESHOLD200MeV_lerrs+multiplicitycharged_THRESHOLD200MeV_uerrs)
    
    pTfluctuationschargedk2_THRESHOLD200MeV_vals = hdf[pTfluctuationschargedk2_THRESHOLD200MeV_vals_dir][:]
    pTfluctuationschargedk2_THRESHOLD200MeV_uerrs = hdf[pTfluctuationschargedk2_THRESHOLD200MeV_uerrs_dir][:]
    pTfluctuationschargedk2_THRESHOLD200MeV_lerrs = hdf[pTfluctuationschargedk2_THRESHOLD200MeV_lerrs_dir][:]

    pTfluctuationschargedk3_THRESHOLD200MeV_vals = hdf[pTfluctuationschargedk3_THRESHOLD200MeV_vals_dir][:]
    pTfluctuationschargedk3_THRESHOLD200MeV_uerrs = hdf[pTfluctuationschargedk3_THRESHOLD200MeV_uerrs_dir][:]
    pTfluctuationschargedk3_THRESHOLD200MeV_lerrs = hdf[pTfluctuationschargedk3_THRESHOLD200MeV_lerrs_dir][:]

    timedependentaveragetemperature_THRESHOLD200MeV_vals = hdf[timedependentaveragetemperature_THRESHOLD200MeV_vals_dir][:]
    timedependentaveragetemperature_THRESHOLD200MeV_uerrs = hdf[timedependentaveragetemperature_THRESHOLD200MeV_uerrs_dir][:]
    timedependentaveragetemperature_THRESHOLD200MeV_lerrs = hdf[timedependentaveragetemperature_THRESHOLD200MeV_lerrs_dir][:]

    timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_vals = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_vals_dir][:]
    timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_uerrs = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_uerrs_dir][:]
    timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_lerrs = hdf[timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_lerrs_dir][:]

    tau_vals = hdf[tau_vals_dir][:]

# %%
multiplicitycharged_THRESHOLD200MeV_vals_05 = multiplicitycharged_THRESHOLD200MeV_vals/multiplicitycharged_THRESHOLD200MeV_vals[16]
multiplicitycharged_THRESHOLD200MeV_symerrs_05 = multiplicitycharged_THRESHOLD200MeV_vals_05*np.sqrt((multiplicitycharged_THRESHOLD200MeV_symerrs/multiplicitycharged_THRESHOLD200MeV_vals)**2+(multiplicitycharged_THRESHOLD200MeV_symerrs[16]/multiplicitycharged_THRESHOLD200MeV_vals[16])**2)

multiplicitycharged_THRESHOLD400MeV_vals_05 = multiplicitycharged_THRESHOLD400MeV_vals/multiplicitycharged_THRESHOLD400MeV_vals[16]
multiplicitycharged_THRESHOLD400MeV_symerrs_05 = multiplicitycharged_THRESHOLD400MeV_vals_05*np.sqrt((multiplicitycharged_THRESHOLD400MeV_symerrs/multiplicitycharged_THRESHOLD400MeV_vals)**2+(multiplicitycharged_THRESHOLD400MeV_symerrs[16]/multiplicitycharged_THRESHOLD400MeV_vals[16])**2)

# 450 MeV
multiplicitycharged_THRESHOLD450MeV_vals_05 = multiplicitycharged_THRESHOLD450MeV_vals / multiplicitycharged_THRESHOLD450MeV_vals[16]
multiplicitycharged_THRESHOLD450MeV_symerrs_05 = multiplicitycharged_THRESHOLD450MeV_vals_05 * np.sqrt(
    (multiplicitycharged_THRESHOLD450MeV_symerrs / multiplicitycharged_THRESHOLD450MeV_vals) ** 2 +
    (multiplicitycharged_THRESHOLD450MeV_symerrs[16] / multiplicitycharged_THRESHOLD450MeV_vals[16]) ** 2
)

# 500 MeV
multiplicitycharged_THRESHOLD500MeV_vals_05 = multiplicitycharged_THRESHOLD500MeV_vals / multiplicitycharged_THRESHOLD500MeV_vals[16]
multiplicitycharged_THRESHOLD500MeV_symerrs_05 = multiplicitycharged_THRESHOLD500MeV_vals_05 * np.sqrt(
    (multiplicitycharged_THRESHOLD500MeV_symerrs / multiplicitycharged_THRESHOLD500MeV_vals) ** 2 +
    (multiplicitycharged_THRESHOLD500MeV_symerrs[16] / multiplicitycharged_THRESHOLD500MeV_vals[16]) ** 2
)

# 550 MeV
multiplicitycharged_THRESHOLD550MeV_vals_05 = multiplicitycharged_THRESHOLD550MeV_vals / multiplicitycharged_THRESHOLD550MeV_vals[16]
multiplicitycharged_THRESHOLD550MeV_symerrs_05 = multiplicitycharged_THRESHOLD550MeV_vals_05 * np.sqrt(
    (multiplicitycharged_THRESHOLD550MeV_symerrs / multiplicitycharged_THRESHOLD550MeV_vals) ** 2 +
    (multiplicitycharged_THRESHOLD550MeV_symerrs[16] / multiplicitycharged_THRESHOLD550MeV_vals[16]) ** 2
)

multiplicitycharged_THRESHOLD600MeV_vals_05 = multiplicitycharged_THRESHOLD600MeV_vals/multiplicitycharged_THRESHOLD600MeV_vals[16]
multiplicitycharged_THRESHOLD600MeV_symerrs_05 = multiplicitycharged_THRESHOLD600MeV_vals_05*np.sqrt((multiplicitycharged_THRESHOLD600MeV_symerrs/multiplicitycharged_THRESHOLD600MeV_vals)**2+(multiplicitycharged_THRESHOLD600MeV_symerrs[16]/multiplicitycharged_THRESHOLD600MeV_vals[16])**2)

multiplicitycharged_THRESHOLD800MeV_vals_05 = multiplicitycharged_THRESHOLD800MeV_vals/multiplicitycharged_THRESHOLD800MeV_vals[16]
multiplicitycharged_THRESHOLD800MeV_symerrs_05 = multiplicitycharged_THRESHOLD800MeV_vals_05*np.sqrt((multiplicitycharged_THRESHOLD800MeV_symerrs/multiplicitycharged_THRESHOLD800MeV_vals)**2+(multiplicitycharged_THRESHOLD800MeV_symerrs[16]/multiplicitycharged_THRESHOLD800MeV_vals[16])**2)

multiplicitycharged_THRESHOLD1000MeV_vals_05 = multiplicitycharged_THRESHOLD1000MeV_vals/multiplicitycharged_THRESHOLD1000MeV_vals[16]
multiplicitycharged_THRESHOLD1000MeV_symerrs_05 = multiplicitycharged_THRESHOLD1000MeV_vals_05*np.sqrt((multiplicitycharged_THRESHOLD1000MeV_symerrs/multiplicitycharged_THRESHOLD1000MeV_vals)**2+(multiplicitycharged_THRESHOLD1000MeV_symerrs[16]/multiplicitycharged_THRESHOLD1000MeV_vals[16])**2)

# %%
print(tau_vals)
# Out:
# [ 0.5   0.75  1.    1.25  1.5   1.75  2.    2.25  2.5   2.75  3.    3.25
#   3.5   3.75  4.    4.25  4.5   4.75  5.    5.25  5.5   5.75  6.    6.25
#   6.5   6.75  7.    7.25  7.5   7.75  8.    8.25  8.5   8.75  9.    9.25
#   9.5   9.75 10.   10.25 10.5  10.75 11.   11.25 11.5  11.75 12.   12.25
#  12.5  12.75 13.  ]

# %%
plt.rcParams.update({"text.usetex": False, "mathtext.fontset": "cm", 
                     "font.family": "serif", "font.size": 12})
plt.figure(figsize=(8, 4), dpi=200)

plt.errorbar(multiplicitycharged_THRESHOLD1000MeV_vals.ravel(),pTfluctuationschargedk2_THRESHOLD1000MeV_vals.ravel(),
             xerr=np.abs([multiplicitycharged_THRESHOLD1000MeV_lerrs.ravel(),multiplicitycharged_THRESHOLD1000MeV_uerrs.ravel()]),
             yerr=np.abs([pTfluctuationschargedk2_THRESHOLD1000MeV_lerrs.ravel(),pTfluctuationschargedk2_THRESHOLD1000MeV_uerrs.ravel()]),
             fmt="o",capsize=5,color="black",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>800$ MeV, $|\eta|<0.5$")
plt.errorbar(multiplicitycharged_THRESHOLD800MeV_vals.ravel(),pTfluctuationschargedk2_THRESHOLD800MeV_vals.ravel(),
             xerr=np.abs([multiplicitycharged_THRESHOLD800MeV_lerrs.ravel(),multiplicitycharged_THRESHOLD800MeV_uerrs.ravel()]),
             yerr=np.abs([pTfluctuationschargedk2_THRESHOLD800MeV_lerrs.ravel(),pTfluctuationschargedk2_THRESHOLD800MeV_uerrs.ravel()]),
             fmt="o",capsize=5,color="purple",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>800$ MeV, $|\eta|<0.5$")
plt.errorbar(multiplicitycharged_THRESHOLD600MeV_vals.ravel(),pTfluctuationschargedk2_THRESHOLD600MeV_vals.ravel(),
             xerr=np.abs([multiplicitycharged_THRESHOLD600MeV_lerrs.ravel(),multiplicitycharged_THRESHOLD600MeV_uerrs.ravel()]),
             yerr=np.abs([pTfluctuationschargedk2_THRESHOLD600MeV_lerrs.ravel(),pTfluctuationschargedk2_THRESHOLD600MeV_uerrs.ravel()]),
             fmt="o",capsize=5,color="blue",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>600$ MeV, $|\eta|<0.5$")
plt.errorbar(multiplicitycharged_THRESHOLD400MeV_vals.ravel(),pTfluctuationschargedk2_THRESHOLD400MeV_vals.ravel(),
             xerr=np.abs([multiplicitycharged_THRESHOLD400MeV_lerrs.ravel(),multiplicitycharged_THRESHOLD400MeV_uerrs.ravel()]),
             yerr=np.abs([pTfluctuationschargedk2_THRESHOLD400MeV_lerrs.ravel(),pTfluctuationschargedk2_THRESHOLD400MeV_uerrs.ravel()]),
             fmt="o",capsize=5,color="green",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>400$ MeV, $|\eta|<0.5$")
plt.errorbar(multiplicitycharged_THRESHOLD200MeV_vals.ravel(),pTfluctuationschargedk2_THRESHOLD200MeV_vals.ravel(),
             xerr=np.abs([multiplicitycharged_THRESHOLD200MeV_lerrs.ravel(),multiplicitycharged_THRESHOLD200MeV_uerrs.ravel()]),
             yerr=np.abs([pTfluctuationschargedk2_THRESHOLD200MeV_lerrs.ravel(),pTfluctuationschargedk2_THRESHOLD200MeV_uerrs.ravel()]),
             fmt="o",capsize=5,color="red",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>200$ MeV, $|\eta|<0.5$")
plt.grid()
plt.xlim([0,550])
plt.ylim([-0.0015,0.001])
plt.legend(prop={'size': '8'},loc="lower right")
plt.ylabel("$k_2$")
plt.xlabel("$N_{ch}$")
# Out:
# Text(0.5, 0, '$N_{ch}$')

# %%
plt.rcParams.update({"text.usetex": False, "mathtext.fontset": "cm", 
                     "font.family": "serif", "font.size": 12})
plt.figure(figsize=(8, 4), dpi=200)

plt.errorbar(multiplicitycharged_THRESHOLD1000MeV_vals_05.ravel(),pTfluctuationschargedk2_THRESHOLD1000MeV_vals.ravel(),
             xerr=np.abs(multiplicitycharged_THRESHOLD1000MeV_symerrs_05.ravel()),
             yerr=np.abs([pTfluctuationschargedk2_THRESHOLD1000MeV_lerrs.ravel(),pTfluctuationschargedk2_THRESHOLD1000MeV_uerrs.ravel()]),
             fmt="o",capsize=5,color="black",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>1000$ MeV, $|\eta|<0.5$")
plt.errorbar(multiplicitycharged_THRESHOLD800MeV_vals_05.ravel(),pTfluctuationschargedk2_THRESHOLD800MeV_vals.ravel(),
             xerr=np.abs(multiplicitycharged_THRESHOLD800MeV_symerrs_05.ravel()),
             yerr=np.abs([pTfluctuationschargedk2_THRESHOLD800MeV_lerrs.ravel(),pTfluctuationschargedk2_THRESHOLD800MeV_uerrs.ravel()]),
             fmt="o",capsize=5,color="purple",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>800$ MeV, $|\eta|<0.5$")
plt.errorbar(multiplicitycharged_THRESHOLD600MeV_vals_05.ravel(),pTfluctuationschargedk2_THRESHOLD600MeV_vals.ravel(),
             xerr=np.abs(multiplicitycharged_THRESHOLD600MeV_symerrs_05.ravel()),
             yerr=np.abs([pTfluctuationschargedk2_THRESHOLD600MeV_lerrs.ravel(),pTfluctuationschargedk2_THRESHOLD600MeV_uerrs.ravel()]),
             fmt="o",capsize=5,color="blue",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>600$ MeV, $|\eta|<0.5$")
plt.errorbar(multiplicitycharged_THRESHOLD400MeV_vals_05.ravel(),pTfluctuationschargedk2_THRESHOLD400MeV_vals.ravel(),
             xerr=np.abs(multiplicitycharged_THRESHOLD400MeV_symerrs_05.ravel()),
             yerr=np.abs([pTfluctuationschargedk2_THRESHOLD400MeV_lerrs.ravel(),pTfluctuationschargedk2_THRESHOLD400MeV_uerrs.ravel()]),
             fmt="o",capsize=5,color="green",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>400$ MeV, $|\eta|<0.5$")
plt.errorbar(multiplicitycharged_THRESHOLD200MeV_vals_05.ravel(),pTfluctuationschargedk2_THRESHOLD200MeV_vals.ravel(),
             xerr=np.abs(multiplicitycharged_THRESHOLD200MeV_symerrs_05.ravel()),
             yerr=np.abs([pTfluctuationschargedk2_THRESHOLD200MeV_lerrs.ravel(),pTfluctuationschargedk2_THRESHOLD200MeV_uerrs.ravel()]),
             fmt="o",capsize=5,color="red",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>200$ MeV, $|\eta|<0.5$")
plt.grid()
# plt.xlim([0,550])
plt.ylim([-0.0015,0.001])
plt.legend(prop={'size': '8'},loc="lower right")
plt.ylabel("$k_2$")
plt.xlabel("$N_{ch}/N_{ch,0-5\%}$")
# Out:
# <>:30: SyntaxWarning: invalid escape sequence '\%'
# <>:30: SyntaxWarning: invalid escape sequence '\%'
# /var/folders/mb/30yyqfg516jdbq01t3whp1r40000gn/T/ipykernel_2857/3408444897.py:30: SyntaxWarning: invalid escape sequence '\%'
#   plt.xlabel("$N_{ch}/N_{ch,0-5\%}$")
# Text(0.5, 0, '$N_{ch}/N_{ch,0-5\\%}$')

# %%
plt.rcParams.update({"text.usetex": False, "mathtext.fontset": "cm", 
                     "font.family": "serif", "font.size": 12})
plt.figure(figsize=(8, 4), dpi=200)

plt.errorbar(multiplicitycharged_THRESHOLD1000MeV_vals.ravel(),pTfluctuationschargedk3_THRESHOLD1000MeV_vals.ravel(),
             xerr=np.abs([multiplicitycharged_THRESHOLD1000MeV_lerrs.ravel(),multiplicitycharged_THRESHOLD1000MeV_uerrs.ravel()]),
             yerr=np.abs([pTfluctuationschargedk3_THRESHOLD1000MeV_lerrs.ravel(),pTfluctuationschargedk3_THRESHOLD1000MeV_uerrs.ravel()]),
             fmt="o",capsize=5,color="black",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>1000$ MeV, $|\eta|<0.5$")
plt.errorbar(multiplicitycharged_THRESHOLD800MeV_vals.ravel(),pTfluctuationschargedk3_THRESHOLD800MeV_vals.ravel(),
             xerr=np.abs([multiplicitycharged_THRESHOLD800MeV_lerrs.ravel(),multiplicitycharged_THRESHOLD800MeV_uerrs.ravel()]),
             yerr=np.abs([pTfluctuationschargedk3_THRESHOLD800MeV_lerrs.ravel(),pTfluctuationschargedk3_THRESHOLD800MeV_uerrs.ravel()]),
             fmt="o",capsize=5,color="purple",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>800$ MeV, $|\eta|<0.5$")
plt.errorbar(multiplicitycharged_THRESHOLD600MeV_vals.ravel(),pTfluctuationschargedk3_THRESHOLD600MeV_vals.ravel(),
             xerr=np.abs([multiplicitycharged_THRESHOLD600MeV_lerrs.ravel(),multiplicitycharged_THRESHOLD600MeV_uerrs.ravel()]),
             yerr=np.abs([pTfluctuationschargedk3_THRESHOLD600MeV_lerrs.ravel(),pTfluctuationschargedk3_THRESHOLD600MeV_uerrs.ravel()]),
             fmt="o",capsize=5,color="blue",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>600$ MeV, $|\eta|<0.5$")
plt.errorbar(multiplicitycharged_THRESHOLD400MeV_vals.ravel(),pTfluctuationschargedk3_THRESHOLD400MeV_vals.ravel(),
             xerr=np.abs([multiplicitycharged_THRESHOLD400MeV_lerrs.ravel(),multiplicitycharged_THRESHOLD400MeV_uerrs.ravel()]),
             yerr=np.abs([pTfluctuationschargedk3_THRESHOLD400MeV_lerrs.ravel(),pTfluctuationschargedk3_THRESHOLD400MeV_uerrs.ravel()]),
             fmt="o",capsize=5,color="green",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>400$ MeV, $|\eta|<0.5$")
plt.errorbar(multiplicitycharged_THRESHOLD200MeV_vals.ravel(),pTfluctuationschargedk3_THRESHOLD200MeV_vals.ravel(),
             xerr=np.abs([multiplicitycharged_THRESHOLD200MeV_lerrs.ravel(),multiplicitycharged_THRESHOLD200MeV_uerrs.ravel()]),
             yerr=np.abs([pTfluctuationschargedk3_THRESHOLD200MeV_lerrs.ravel(),pTfluctuationschargedk3_THRESHOLD200MeV_uerrs.ravel()]),
             fmt="o",capsize=5,color="red",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>200$ MeV, $|\eta|<0.5$")

plt.grid()
plt.xlim([0,550])
plt.ylim([-0.00001,0.000012])
plt.legend(prop={'size': '8'},loc="upper right")
plt.ylabel("$k_3$")
plt.xlabel("$N_{ch}$")
# Out:
# Text(0.5, 0, '$N_{ch}$')

# %%
#centrality bin chooser
index = 16

timedependentaveragetemperature_THRESHOLD200MeV_vals_at_index = timedependentaveragetemperature_THRESHOLD200MeV_vals[index,0,:]
timedependentaveragetemperature_THRESHOLD200MeV_lerrs_at_index = timedependentaveragetemperature_THRESHOLD200MeV_lerrs[index,0,:]
timedependentaveragetemperature_THRESHOLD200MeV_uerrs_at_index = timedependentaveragetemperature_THRESHOLD200MeV_uerrs[index,0,:]

timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_vals_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_vals[index,0,:]
timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_lerrs_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_lerrs[index,0,:]
timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_uerrs_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_uerrs[index,0,:]

timedependentaveragetemperature_THRESHOLD400MeV_vals_at_index = timedependentaveragetemperature_THRESHOLD400MeV_vals[index,0,:]
timedependentaveragetemperature_THRESHOLD400MeV_lerrs_at_index = timedependentaveragetemperature_THRESHOLD400MeV_lerrs[index,0,:]
timedependentaveragetemperature_THRESHOLD400MeV_uerrs_at_index = timedependentaveragetemperature_THRESHOLD400MeV_uerrs[index,0,:]

timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_vals_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_vals[index,0,:]
timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_lerrs_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_lerrs[index,0,:]
timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_uerrs_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_uerrs[index,0,:]

timedependentaveragetemperature_THRESHOLD600MeV_vals_at_index = timedependentaveragetemperature_THRESHOLD600MeV_vals[index,0,:]
timedependentaveragetemperature_THRESHOLD600MeV_lerrs_at_index = timedependentaveragetemperature_THRESHOLD600MeV_lerrs[index,0,:]
timedependentaveragetemperature_THRESHOLD600MeV_uerrs_at_index = timedependentaveragetemperature_THRESHOLD600MeV_uerrs[index,0,:]

timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_vals_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_vals[index,0,:]
timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_lerrs_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_lerrs[index,0,:]
timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_uerrs_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_uerrs[index,0,:]

timedependentaveragetemperature_THRESHOLD800MeV_vals_at_index = timedependentaveragetemperature_THRESHOLD800MeV_vals[index,0,:]
timedependentaveragetemperature_THRESHOLD800MeV_lerrs_at_index = timedependentaveragetemperature_THRESHOLD800MeV_lerrs[index,0,:]
timedependentaveragetemperature_THRESHOLD800MeV_uerrs_at_index = timedependentaveragetemperature_THRESHOLD800MeV_uerrs[index,0,:]

timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_vals_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_vals[index,0,:]
timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_lerrs_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_lerrs[index,0,:]
timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_uerrs_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_uerrs[index,0,:]

timedependentaveragetemperature_THRESHOLD1000MeV_vals_at_index = timedependentaveragetemperature_THRESHOLD1000MeV_vals[index,0,:]
timedependentaveragetemperature_THRESHOLD1000MeV_lerrs_at_index = timedependentaveragetemperature_THRESHOLD1000MeV_lerrs[index,0,:]
timedependentaveragetemperature_THRESHOLD1000MeV_uerrs_at_index = timedependentaveragetemperature_THRESHOLD1000MeV_uerrs[index,0,:]

timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_vals_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_vals[index,0,:]
timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_lerrs_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_lerrs[index,0,:]
timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_uerrs_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_uerrs[index,0,:]

existence_maskTHRESHOLD200MeV = timedependentaveragetemperature_THRESHOLD200MeV_lerrs_at_index != -1
existence_maskTHRESHOLD400MeV = timedependentaveragetemperature_THRESHOLD400MeV_lerrs_at_index != -1
existence_maskTHRESHOLD600MeV = timedependentaveragetemperature_THRESHOLD600MeV_lerrs_at_index != -1
existence_maskTHRESHOLD800MeV = timedependentaveragetemperature_THRESHOLD800MeV_lerrs_at_index != -1
existence_maskTHRESHOLD1000MeV = timedependentaveragetemperature_THRESHOLD1000MeV_lerrs_at_index != -1

masked_tau_THRESHOLD200MeV_vals = tau_vals[existence_maskTHRESHOLD200MeV]
masked_tau_THRESHOLD400MeV_vals = tau_vals[existence_maskTHRESHOLD400MeV]
masked_tau_THRESHOLD600MeV_vals = tau_vals[existence_maskTHRESHOLD600MeV]
masked_tau_THRESHOLD800MeV_vals = tau_vals[existence_maskTHRESHOLD800MeV]
masked_tau_THRESHOLD1000MeV_vals = tau_vals[existence_maskTHRESHOLD1000MeV]

masked_timedependentaveragetemperature_THRESHOLD200MeV_vals_at_index = timedependentaveragetemperature_THRESHOLD200MeV_vals_at_index[existence_maskTHRESHOLD200MeV]
masked_timedependentaveragetemperature_THRESHOLD200MeV_lerrs_at_index = timedependentaveragetemperature_THRESHOLD200MeV_lerrs_at_index[existence_maskTHRESHOLD200MeV]
masked_timedependentaveragetemperature_THRESHOLD200MeV_uerrs_at_index = timedependentaveragetemperature_THRESHOLD200MeV_uerrs_at_index[existence_maskTHRESHOLD200MeV]
masked_timedependentaveragetemperature_THRESHOLD200MeV_symerrs_at_index = 0.5 * (masked_timedependentaveragetemperature_THRESHOLD200MeV_lerrs_at_index+masked_timedependentaveragetemperature_THRESHOLD200MeV_uerrs_at_index)

masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_vals_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_vals_at_index[existence_maskTHRESHOLD200MeV]
masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_lerrs_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_lerrs_at_index[existence_maskTHRESHOLD200MeV]
masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_uerrs_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_uerrs_at_index[existence_maskTHRESHOLD200MeV]
masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_symerrs_at_index = 0.5 * (masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_lerrs_at_index+masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_uerrs_at_index)

masked_timedependentaveragetemperature_THRESHOLD400MeV_vals_at_index = timedependentaveragetemperature_THRESHOLD400MeV_vals_at_index[existence_maskTHRESHOLD400MeV]
masked_timedependentaveragetemperature_THRESHOLD400MeV_lerrs_at_index = timedependentaveragetemperature_THRESHOLD400MeV_lerrs_at_index[existence_maskTHRESHOLD400MeV]
masked_timedependentaveragetemperature_THRESHOLD400MeV_uerrs_at_index = timedependentaveragetemperature_THRESHOLD400MeV_uerrs_at_index[existence_maskTHRESHOLD400MeV]
masked_timedependentaveragetemperature_THRESHOLD400MeV_symerrs_at_index = 0.5 * (masked_timedependentaveragetemperature_THRESHOLD400MeV_lerrs_at_index+masked_timedependentaveragetemperature_THRESHOLD400MeV_uerrs_at_index)

masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_vals_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_vals_at_index[existence_maskTHRESHOLD400MeV]
masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_lerrs_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_lerrs_at_index[existence_maskTHRESHOLD400MeV]
masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_uerrs_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_uerrs_at_index[existence_maskTHRESHOLD400MeV]
masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_symerrs_at_index = 0.5 * (masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_lerrs_at_index+masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_uerrs_at_index)

masked_timedependentaveragetemperature_THRESHOLD600MeV_vals_at_index = timedependentaveragetemperature_THRESHOLD600MeV_vals_at_index[existence_maskTHRESHOLD600MeV]
masked_timedependentaveragetemperature_THRESHOLD600MeV_lerrs_at_index = timedependentaveragetemperature_THRESHOLD600MeV_lerrs_at_index[existence_maskTHRESHOLD600MeV]
masked_timedependentaveragetemperature_THRESHOLD600MeV_uerrs_at_index = timedependentaveragetemperature_THRESHOLD600MeV_uerrs_at_index[existence_maskTHRESHOLD600MeV]
masked_timedependentaveragetemperature_THRESHOLD600MeV_symerrs_at_index = 0.5 * (masked_timedependentaveragetemperature_THRESHOLD600MeV_lerrs_at_index+masked_timedependentaveragetemperature_THRESHOLD600MeV_uerrs_at_index)

masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_vals_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_vals_at_index[existence_maskTHRESHOLD600MeV]
masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_lerrs_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_lerrs_at_index[existence_maskTHRESHOLD600MeV]
masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_uerrs_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_uerrs_at_index[existence_maskTHRESHOLD600MeV]
masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_symerrs_at_index = 0.5 * (masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_lerrs_at_index+masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_uerrs_at_index)

masked_timedependentaveragetemperature_THRESHOLD800MeV_vals_at_index = timedependentaveragetemperature_THRESHOLD800MeV_vals_at_index[existence_maskTHRESHOLD800MeV]
masked_timedependentaveragetemperature_THRESHOLD800MeV_lerrs_at_index = timedependentaveragetemperature_THRESHOLD800MeV_lerrs_at_index[existence_maskTHRESHOLD800MeV]
masked_timedependentaveragetemperature_THRESHOLD800MeV_uerrs_at_index = timedependentaveragetemperature_THRESHOLD800MeV_uerrs_at_index[existence_maskTHRESHOLD800MeV]
masked_timedependentaveragetemperature_THRESHOLD800MeV_symerrs_at_index = 0.5 * (masked_timedependentaveragetemperature_THRESHOLD800MeV_lerrs_at_index+masked_timedependentaveragetemperature_THRESHOLD800MeV_uerrs_at_index)

masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_vals_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_vals_at_index[existence_maskTHRESHOLD800MeV]
masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_lerrs_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_lerrs_at_index[existence_maskTHRESHOLD800MeV]
masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_uerrs_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_uerrs_at_index[existence_maskTHRESHOLD800MeV]
masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_symerrs_at_index = 0.5 * (masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_lerrs_at_index+masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_uerrs_at_index)

masked_timedependentaveragetemperature_THRESHOLD1000MeV_vals_at_index = timedependentaveragetemperature_THRESHOLD1000MeV_vals_at_index[existence_maskTHRESHOLD1000MeV]
masked_timedependentaveragetemperature_THRESHOLD1000MeV_lerrs_at_index = timedependentaveragetemperature_THRESHOLD1000MeV_lerrs_at_index[existence_maskTHRESHOLD1000MeV]
masked_timedependentaveragetemperature_THRESHOLD1000MeV_uerrs_at_index = timedependentaveragetemperature_THRESHOLD1000MeV_uerrs_at_index[existence_maskTHRESHOLD1000MeV]
masked_timedependentaveragetemperature_THRESHOLD1000MeV_symerrs_at_index = 0.5 * (masked_timedependentaveragetemperature_THRESHOLD1000MeV_lerrs_at_index+masked_timedependentaveragetemperature_THRESHOLD1000MeV_uerrs_at_index)

masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_vals_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_vals_at_index[existence_maskTHRESHOLD1000MeV]
masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_lerrs_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_lerrs_at_index[existence_maskTHRESHOLD1000MeV]
masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_uerrs_at_index = timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_uerrs_at_index[existence_maskTHRESHOLD1000MeV]
masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_symerrs_at_index = 0.5 * (masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_lerrs_at_index+masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_uerrs_at_index)

# %%
#Ratios: TDAT

masked_ratio_200MeV_TDAT_vals_at_index = masked_timedependentaveragetemperature_THRESHOLD200MeV_vals_at_index/masked_timedependentaveragetemperature_THRESHOLD200MeV_vals_at_index
masked_ratio_200MeV_TDAT_symerrs_at_index = 0

masked_ratio_400MeV_TDAT_vals_at_index = masked_timedependentaveragetemperature_THRESHOLD400MeV_vals_at_index/masked_timedependentaveragetemperature_THRESHOLD200MeV_vals_at_index
masked_ratio_400MeV_TDAT_symerrs_at_index = masked_ratio_400MeV_TDAT_vals_at_index * np.sqrt((masked_timedependentaveragetemperature_THRESHOLD400MeV_symerrs_at_index/masked_timedependentaveragetemperature_THRESHOLD400MeV_vals_at_index)**2+(masked_timedependentaveragetemperature_THRESHOLD200MeV_symerrs_at_index/masked_timedependentaveragetemperature_THRESHOLD200MeV_vals_at_index)**2)

masked_ratio_600MeV_TDAT_vals_at_index = masked_timedependentaveragetemperature_THRESHOLD600MeV_vals_at_index/masked_timedependentaveragetemperature_THRESHOLD200MeV_vals_at_index
masked_ratio_600MeV_TDAT_symerrs_at_index = masked_ratio_600MeV_TDAT_vals_at_index * np.sqrt((masked_timedependentaveragetemperature_THRESHOLD600MeV_symerrs_at_index/masked_timedependentaveragetemperature_THRESHOLD600MeV_vals_at_index)**2+(masked_timedependentaveragetemperature_THRESHOLD200MeV_symerrs_at_index/masked_timedependentaveragetemperature_THRESHOLD200MeV_vals_at_index)**2)

masked_ratio_800MeV_TDAT_vals_at_index = masked_timedependentaveragetemperature_THRESHOLD800MeV_vals_at_index/masked_timedependentaveragetemperature_THRESHOLD200MeV_vals_at_index
masked_ratio_800MeV_TDAT_symerrs_at_index = masked_ratio_800MeV_TDAT_vals_at_index * np.sqrt((masked_timedependentaveragetemperature_THRESHOLD800MeV_symerrs_at_index/masked_timedependentaveragetemperature_THRESHOLD800MeV_vals_at_index)**2+(masked_timedependentaveragetemperature_THRESHOLD200MeV_symerrs_at_index/masked_timedependentaveragetemperature_THRESHOLD200MeV_vals_at_index)**2)

masked_ratio_1000MeV_TDAT_vals_at_index = masked_timedependentaveragetemperature_THRESHOLD1000MeV_vals_at_index/masked_timedependentaveragetemperature_THRESHOLD200MeV_vals_at_index
masked_ratio_1000MeV_TDAT_symerrs_at_index = masked_ratio_1000MeV_TDAT_vals_at_index * np.sqrt((masked_timedependentaveragetemperature_THRESHOLD1000MeV_symerrs_at_index/masked_timedependentaveragetemperature_THRESHOLD1000MeV_vals_at_index)**2+(masked_timedependentaveragetemperature_THRESHOLD200MeV_symerrs_at_index/masked_timedependentaveragetemperature_THRESHOLD200MeV_vals_at_index)**2)

# %%
#Ratios: TDATSD

masked_ratio_200MeV_TDATSD_vals_at_index = masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_vals_at_index/masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_vals_at_index
masked_ratio_200MeV_TDATSD_symerrs_at_index = 0

masked_ratio_400MeV_TDATSD_vals_at_index = masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_vals_at_index/masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_vals_at_index
masked_ratio_400MeV_TDATSD_symerrs_at_index = masked_ratio_400MeV_TDATSD_vals_at_index * np.sqrt((masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_symerrs_at_index/masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_vals_at_index)**2+(masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_symerrs_at_index/masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_vals_at_index)**2)

masked_ratio_600MeV_TDATSD_vals_at_index = masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_vals_at_index/masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_vals_at_index
masked_ratio_600MeV_TDATSD_symerrs_at_index = masked_ratio_600MeV_TDATSD_vals_at_index * np.sqrt((masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_symerrs_at_index/masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_vals_at_index)**2+(masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_symerrs_at_index/masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_vals_at_index)**2)

masked_ratio_800MeV_TDATSD_vals_at_index = masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_vals_at_index/masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_vals_at_index
masked_ratio_800MeV_TDATSD_symerrs_at_index = masked_ratio_800MeV_TDATSD_vals_at_index * np.sqrt((masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_symerrs_at_index/masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_vals_at_index)**2+(masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_symerrs_at_index/masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_vals_at_index)**2)

masked_ratio_1000MeV_TDATSD_vals_at_index = masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_vals_at_index/masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_vals_at_index
masked_ratio_1000MeV_TDATSD_symerrs_at_index = masked_ratio_1000MeV_TDATSD_vals_at_index * np.sqrt((masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_symerrs_at_index/masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_vals_at_index)**2+(masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_symerrs_at_index/masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_vals_at_index)**2)

# %%
plt.rcParams.update({"text.usetex": False, "mathtext.fontset": "cm", 
                     "font.family": "serif", "font.size": 12})
plt.figure(figsize=(8, 4), dpi=200)

plt.errorbar(masked_tau_THRESHOLD200MeV_vals.ravel(),
             masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_vals_at_index.ravel(),
            yerr=np.abs([masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_lerrs_at_index.ravel(),
                          masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD200MeV_uerrs_at_index.ravel()]),
             fmt="o",capsize=5,color="red",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>200$ MeV, $|\eta|<0.5$")
plt.errorbar(masked_tau_THRESHOLD400MeV_vals.ravel(),
             masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_vals_at_index.ravel(),
             yerr=np.abs([masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_lerrs_at_index.ravel(),
                          masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD400MeV_uerrs_at_index.ravel()]),
             fmt="o",capsize=5,color="green",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>400$ MeV, $|\eta|<0.5$")
plt.errorbar(masked_tau_THRESHOLD600MeV_vals.ravel(),
             masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_vals_at_index.ravel(),
             yerr=np.abs([masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_lerrs_at_index.ravel(),
                          masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD600MeV_uerrs_at_index.ravel()]),
             fmt="o",capsize=5,color="blue",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>600$ MeV, $|\eta|<0.5$")
plt.errorbar(masked_tau_THRESHOLD800MeV_vals.ravel(),
             masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_vals_at_index.ravel(),
             yerr=np.abs([masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_lerrs_at_index.ravel(),
                          masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD800MeV_uerrs_at_index.ravel()]),
             fmt="o",capsize=5,color="purple",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>800$ MeV, $|\eta|<0.5$")
plt.errorbar(masked_tau_THRESHOLD1000MeV_vals.ravel(),
             masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_vals_at_index.ravel(),
             yerr=np.abs([masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_lerrs_at_index.ravel(),
                          masked_timedependentaveragetemperaturestandarddeviation_THRESHOLD1000MeV_uerrs_at_index.ravel()]),
             fmt="o",capsize=5,color="black",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>1$ GeV, $|\eta|<0.5$")

plt.grid()
plt.title(r"Average Temperature Standard Deviation: 0-5% centrality")
plt.legend(prop={'size': '8'},loc="upper right")
plt.ylabel(r"$\sigma\left(\langle T\rangle\right)$ [GeV]")
plt.xlabel(r"$\tau$ [fm/c]")

plt.rcParams.update({"text.usetex": False, "mathtext.fontset": "cm", 
                     "font.family": "serif", "font.size": 12})
plt.figure(figsize=(8, 4), dpi=200)

plt.errorbar(masked_tau_THRESHOLD200MeV_vals.ravel(),
             masked_ratio_200MeV_TDATSD_vals_at_index.ravel(),
                          yerr=masked_ratio_200MeV_TDATSD_symerrs_at_index,
             fmt="o",capsize=5,color="red",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>200$ MeV, $|\eta|<0.5$")
plt.errorbar(masked_tau_THRESHOLD400MeV_vals.ravel(),
             masked_ratio_400MeV_TDATSD_vals_at_index.ravel(),
             yerr=masked_ratio_400MeV_TDATSD_symerrs_at_index.ravel(),
             fmt="o",capsize=5,color="green",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>400$ MeV, $|\eta|<0.5$")
plt.errorbar(masked_tau_THRESHOLD600MeV_vals.ravel(),
             masked_ratio_600MeV_TDATSD_vals_at_index.ravel(),
             yerr=masked_ratio_600MeV_TDATSD_symerrs_at_index.ravel(),
             fmt="o",capsize=5,color="blue",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>600$ MeV, $|\eta|<0.5$")
plt.errorbar(masked_tau_THRESHOLD800MeV_vals.ravel(),
             masked_ratio_800MeV_TDATSD_vals_at_index.ravel(),
             yerr=masked_ratio_800MeV_TDATSD_symerrs_at_index.ravel(),
             fmt="o",capsize=5,color="purple",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>800$ MeV, $|\eta|<0.5$")
plt.errorbar(masked_tau_THRESHOLD1000MeV_vals.ravel(),
             masked_ratio_800MeV_TDATSD_vals_at_index.ravel(),
             yerr=masked_ratio_1000MeV_TDATSD_symerrs_at_index.ravel(),
             fmt="o",capsize=5,color="black",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>1$ GeV, $|\eta|<0.5$")

plt.grid()
plt.title(r"Standard Deviation (Ratio): 0-5% centrality")
plt.legend(prop={'size': '8'},loc="upper left")
plt.ylabel(r"Ratio")
plt.ylim([0.8,1.4])
plt.xlabel(r"$\tau$ [fm/c]")
# Out:
# Text(0.5, 0, '$\\tau$ [fm/c]')

# %%
plt.rcParams.update({"text.usetex": False, "mathtext.fontset": "cm", 
                     "font.family": "serif", "font.size": 12})
plt.figure(figsize=(8, 4), dpi=200)

plt.errorbar(masked_tau_THRESHOLD200MeV_vals.ravel(),
             masked_timedependentaveragetemperature_THRESHOLD200MeV_vals_at_index.ravel(),
                          yerr=np.abs([masked_timedependentaveragetemperature_THRESHOLD200MeV_lerrs_at_index.ravel(),
                          masked_timedependentaveragetemperature_THRESHOLD200MeV_uerrs_at_index.ravel()]),
             fmt="o",capsize=5,color="red",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>200$ MeV, $|\eta|<0.5$")
plt.errorbar(masked_tau_THRESHOLD400MeV_vals.ravel(),
             masked_timedependentaveragetemperature_THRESHOLD400MeV_vals_at_index.ravel(),
             yerr=np.abs([masked_timedependentaveragetemperature_THRESHOLD400MeV_lerrs_at_index.ravel(),
                          masked_timedependentaveragetemperature_THRESHOLD400MeV_uerrs_at_index.ravel()]),
             fmt="o",capsize=5,color="green",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>400$ MeV, $|\eta|<0.5$")
plt.errorbar(masked_tau_THRESHOLD600MeV_vals.ravel(),
             masked_timedependentaveragetemperature_THRESHOLD600MeV_vals_at_index.ravel(),
             yerr=np.abs([masked_timedependentaveragetemperature_THRESHOLD600MeV_lerrs_at_index.ravel(),
                          masked_timedependentaveragetemperature_THRESHOLD600MeV_uerrs_at_index.ravel()]),
             fmt="o",capsize=5,color="blue",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>600$ MeV, $|\eta|<0.5$")
plt.errorbar(masked_tau_THRESHOLD800MeV_vals.ravel(),
             masked_timedependentaveragetemperature_THRESHOLD800MeV_vals_at_index.ravel(),
             yerr=np.abs([masked_timedependentaveragetemperature_THRESHOLD800MeV_lerrs_at_index.ravel(),
                          masked_timedependentaveragetemperature_THRESHOLD800MeV_uerrs_at_index.ravel()]),
             fmt="o",capsize=5,color="purple",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>800$ MeV, $|\eta|<0.5$")
plt.errorbar(masked_tau_THRESHOLD1000MeV_vals.ravel(),
             masked_timedependentaveragetemperature_THRESHOLD1000MeV_vals_at_index.ravel(),
             yerr=np.abs([masked_timedependentaveragetemperature_THRESHOLD1000MeV_lerrs_at_index.ravel(),
                          masked_timedependentaveragetemperature_THRESHOLD1000MeV_uerrs_at_index.ravel()]),
             fmt="o",capsize=5,color="black",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>1000$ MeV, $|\eta|<0.5$")

plt.grid()
plt.legend(prop={'size': '8'},loc="upper right")
plt.title(r"Time-dependent Average Temperature: 0-5% centrality")
plt.ylabel(r"$\langle\langle T\rangle\rangle$ [GeV]")
plt.xlabel(r"$\tau$ [fm/c]")

plt.rcParams.update({"text.usetex": False, "mathtext.fontset": "cm", 
                     "font.family": "serif", "font.size": 12})
plt.figure(figsize=(8, 4), dpi=200)

plt.errorbar(masked_tau_THRESHOLD200MeV_vals.ravel(),
             masked_ratio_200MeV_TDAT_vals_at_index.ravel(),
                          yerr=masked_ratio_200MeV_TDAT_symerrs_at_index,
             fmt="o",capsize=5,color="red",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>200$ MeV, $|\eta|<0.5$")
plt.errorbar(masked_tau_THRESHOLD400MeV_vals.ravel(),
             masked_ratio_400MeV_TDAT_vals_at_index.ravel(),
             yerr=masked_ratio_400MeV_TDAT_symerrs_at_index.ravel(),
             fmt="o",capsize=5,color="green",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>400$ MeV, $|\eta|<0.5$")
plt.errorbar(masked_tau_THRESHOLD600MeV_vals.ravel(),
             masked_ratio_600MeV_TDAT_vals_at_index.ravel(),
             yerr=masked_ratio_600MeV_TDAT_symerrs_at_index.ravel(),
             fmt="o",capsize=5,color="blue",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>600$ MeV, $|\eta|<0.5$")
plt.errorbar(masked_tau_THRESHOLD800MeV_vals.ravel(),
             masked_ratio_800MeV_TDAT_vals_at_index.ravel(),
             yerr=masked_ratio_800MeV_TDAT_symerrs_at_index.ravel(),
             fmt="o",capsize=5,color="purple",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>800$ MeV, $|\eta|<0.5$")
plt.errorbar(masked_tau_THRESHOLD1000MeV_vals.ravel(),
             masked_ratio_800MeV_TDAT_vals_at_index.ravel(),
             yerr=masked_ratio_1000MeV_TDAT_symerrs_at_index.ravel(),
             fmt="o",capsize=5,color="black",label=r"$\sqrt{s_{NN}}=200$ GeV. $N_{ch}\in p_T>1$ GeV, $|\eta|<0.5$")

plt.grid()
plt.title(r"Average Temperature (Ratio): 0-5% centrality")
plt.legend(prop={'size': '8'},loc="upper right")
plt.ylabel(r"Ratio")
plt.xlabel(r"$\tau$ [fm/c]")
# Out:
# Text(0.5, 0, '$\\tau$ [fm/c]')

# %%
Teff_Lattice = np.array([130.0, 132.4, 134.8, 137.3, 139.7, 142.1, 144.5, 147.0, 149.4, 151.8,
      154.2, 156.7, 159.1, 161.5, 163.9, 166.4, 168.8, 171.2, 173.6, 176.1,
      178.5, 180.9, 183.3, 185.8, 188.2, 190.6, 193.0, 195.5, 197.9, 200.3,
      202.7, 205.2, 207.6, 210.0, 212.4, 214.8, 217.3, 219.7, 222.1, 224.5,
      227.0, 229.4, 231.8, 234.2, 236.7, 239.1, 241.5, 243.9, 246.4, 248.8,
      251.2, 253.6, 256.1, 258.5, 260.9, 263.3, 265.8, 268.2, 270.6, 273.0,
      275.5, 277.9, 280.3, 282.7, 285.2, 287.6, 290.0, 292.4, 294.8, 297.3,
      299.7, 302.1, 304.5, 307.0, 309.4, 311.8, 314.2, 316.7, 319.1, 321.5,
      323.9, 326.4, 328.8, 331.2, 333.6, 336.1, 338.5, 340.9, 343.3, 345.8,
      348.2, 350.6, 353.0, 355.5, 357.9, 360.3, 362.7, 365.2, 367.6, 370.0]) / 1000

Teff_Lattice_Err = np.array([1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212,
      1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212,
      1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212,
      1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212,
      1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212,
      1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212,
      1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212,
      1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212,
      1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212,
      1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212, 1.212]) / 1000

cs2_Lattice = np.array([0.1780, 0.1731, 0.1682, 0.1650, 0.1627, 0.1615, 0.1611, 0.1609, 0.1619, 0.1646,
      0.1671, 0.1697, 0.1731, 0.1761, 0.1801, 0.1842, 0.1886, 0.1929, 0.1974, 0.2018,
      0.2064, 0.2104, 0.2146, 0.2188, 0.2229, 0.2269, 0.2307, 0.2340, 0.2374, 0.2409,
      0.2439, 0.2469, 0.2494, 0.2518, 0.2538, 0.2558, 0.2579, 0.2597, 0.2612, 0.2624,
      0.2634, 0.2648, 0.2663, 0.2674, 0.2683, 0.2699, 0.2712, 0.2723, 0.2733, 0.2742,
      0.2752, 0.2763, 0.2773, 0.2783, 0.2794, 0.2803, 0.2814, 0.2825, 0.2834, 0.2844,
      0.2855, 0.2865, 0.2876, 0.2883, 0.2888, 0.2897, 0.2908, 0.2913, 0.2919, 0.2928,
      0.2938, 0.2943, 0.2950, 0.2960, 0.2967, 0.2972, 0.2977, 0.2982, 0.2987, 0.2992,
      0.2998, 0.3004, 0.3010, 0.3016, 0.3022, 0.3029, 0.3034, 0.3039, 0.3044, 0.3050,
      0.3054, 0.3059, 0.3062, 0.3062, 0.3064, 0.3069, 0.3074, 0.3080, 0.3082, 0.3082])

cs2_Lattice_Err = np.array([0.0097, 0.0101, 0.0093, 0.0082, 0.0069, 0.0059, 0.0056, 0.0058, 0.0055, 0.0066,
      0.0071, 0.0076, 0.0079, 0.0087, 0.0091, 0.0093, 0.0095, 0.0095, 0.0094, 0.0094,
      0.0093, 0.0091, 0.0089, 0.0090, 0.0090, 0.0091, 0.0092, 0.0092, 0.0093, 0.0092,
      0.0089, 0.0088, 0.0085, 0.0083, 0.0079, 0.0076, 0.0074, 0.0071, 0.0070, 0.0068,
      0.0066, 0.0065, 0.0064, 0.0062, 0.0060, 0.0059, 0.0058, 0.0057, 0.0056, 0.0055,
      0.0053, 0.0052, 0.0051, 0.0050, 0.0050, 0.0049, 0.0049, 0.0049, 0.0049, 0.0048,
      0.0048, 0.0049, 0.0049, 0.0050, 0.0050, 0.0052, 0.0053, 0.0053, 0.0053, 0.0054,
      0.0055, 0.0056, 0.0058, 0.0058, 0.0059, 0.0060, 0.0061, 0.0061, 0.0062, 0.0063,
      0.0063, 0.0064, 0.0064, 0.0065, 0.0065, 0.0066, 0.0066, 0.0066, 0.0067, 0.0067,
      0.0066, 0.0067, 0.0067, 0.0067, 0.0067, 0.0067, 0.0066, 0.0066, 0.0066, 0.0066])

# Find closest index in Teff_Lattice for each A
idx_min = np.abs(masked_timedependentaveragetemperature_THRESHOLD400MeV_vals_at_index[:, None] 
                 - Teff_Lattice[None, :]).argmin(axis=1)

closest_Teff = Teff_Lattice[idx_min]
closest_Teff_Err = Teff_Lattice_Err[idx_min]
closest_cs2 = cs2_Lattice[idx_min]
closest_cs2_Err = cs2_Lattice_Err[idx_min]

# Only keep if within tolerance
diff = np.abs(masked_timedependentaveragetemperature_THRESHOLD400MeV_vals_at_index - closest_Teff)
tol = 0.005 * Teff_Lattice[idx_min]  # relative tol example
mask = diff < tol

# Apply mask to all arrays
MASKED_masked_timedependentaveragetemperature_THRESHOLD400MeV_vals_at_index = \
    masked_timedependentaveragetemperature_THRESHOLD400MeV_vals_at_index[mask]
MASKED_masked_tau_THRESHOLD400MeV_vals = masked_tau_THRESHOLD400MeV_vals[mask]
Teff_values_for_masked = closest_Teff[mask]
Teff_errs_for_masked = closest_Teff_Err[mask]
cs2_values_for_masked = closest_cs2[mask]
cs2_errs_for_masked = closest_cs2_Err[mask]
print(cs2_values_for_masked)
# Out:
# [0.3044 0.295  0.2876 0.2803 0.2752 0.2699 0.2663 0.2612 0.2579 0.2518
#  0.2469 0.2409 0.234  0.2229 0.2104 0.2064 0.2018 0.1974 0.1886 0.1842
#  0.1801 0.1761 0.1731 0.1697 0.1671 0.1671 0.1646 0.1646 0.1619 0.1619]

# %%
plt.rcParams.update({"text.usetex": False, "mathtext.fontset": "cm", 
                     "font.family": "serif", "font.size": 12})
plt.figure(figsize=(8, 4), dpi=200)
plt.errorbar(MASKED_masked_tau_THRESHOLD400MeV_vals,
             cs2_values_for_masked,
             yerr=[cs2_errs_for_masked],
             fmt="o",capsize=5,color="red",
             label="Closest $c_s^2$ value from LQCD relative to Trajectum data\n" \
             "$N_{ch}\in\>p_T>400$ MeV/c, $|\eta|<0.5$")
plt.xlabel(r"$\tau$ (fm)")
plt.ylabel("$c_s^2$")
plt.title("Time-evolution of $c_s^2$")
plt.legend(prop={'size': '8'},loc="upper right")
plt.grid()
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\i'
# <>:9: SyntaxWarning: invalid escape sequence '\i'
# /var/folders/mb/30yyqfg516jdbq01t3whp1r40000gn/T/ipykernel_2857/1850711772.py:9: SyntaxWarning: invalid escape sequence '\i'
#   "$N_{ch}\in\>p_T>400$ MeV/c, $|\eta|<0.5$")

# %%
print(masked_timedependentaveragetemperature_THRESHOLD1000MeV_vals_at_index)
# Out:
# [0.34292121 0.30531964 0.28136063 0.26415934 0.25083012 0.23999098
#  0.23088658 0.22305626 0.21620562 0.21013698 0.20471101 0.19982849
#  0.195415   0.19141322 0.18777825 0.18447158 0.18146069 0.17871765
#  0.17621701 0.17393621 0.17185237 0.16994319 0.16818611 0.1665578
#  0.16503794 0.16360876 0.16225669 0.16097023 0.15974027 0.15855971
#  0.157423   0.15632706 0.15527192 0.15427201 0.15336202 0.15256668
#  0.15188909 0.15134846 0.15087312 0.15055528 0.15034155 0.15016316
#  0.15006472 0.150001  ]

# %%
# with open("/Users/christianschmidt/Desktop/chargedk2_CE200MeV_NORM.csv", "w") as file:
#     file.write("Nch/Nch05,k2,Nch/Nch05err,k2lerr,k2uerr\n")
#     for i in range(len(multiplicitycharged_THRESHOLD200MeV_vals_05)):
#         file.write(f"{float(multiplicitycharged_THRESHOLD200MeV_vals_05[i])},{float(pTfluctuationschargedk2_THRESHOLD200MeV_vals[i])},{float(multiplicitycharged_THRESHOLD200MeV_symerrs_05[i])},{float(pTfluctuationschargedk2_THRESHOLD200MeV_lerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD200MeV_uerrs[i])}\n")

# with open("/Users/christianschmidt/Desktop/chargedk2_CE400MeV_NORM.csv", "w") as file:
#     file.write("Nch/Nch05,k2,Nch/Nch05err,k2lerr,k2uerr\n")
#     for i in range(len(multiplicitycharged_THRESHOLD400MeV_vals_05)):
#         file.write(f"{float(multiplicitycharged_THRESHOLD400MeV_vals_05[i])},{float(pTfluctuationschargedk2_THRESHOLD400MeV_vals[i])},{float(multiplicitycharged_THRESHOLD400MeV_symerrs_05[i])},{float(pTfluctuationschargedk2_THRESHOLD400MeV_lerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD400MeV_uerrs[i])}\n")

with open("/Users/christianschmidt/Desktop/chargedk2_CE450MeV_NORM.csv", "w") as file:
    file.write("Nch/Nch05,k2,Nch/Nch05err,k2lerr,k2uerr\n")
    for i in range(len(multiplicitycharged_THRESHOLD450MeV_vals_05)):
        file.write(f"{float(multiplicitycharged_THRESHOLD450MeV_vals_05[i])},{float(pTfluctuationschargedk2_THRESHOLD450MeV_vals[i])},{float(multiplicitycharged_THRESHOLD450MeV_symerrs_05[i])},{float(pTfluctuationschargedk2_THRESHOLD450MeV_lerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD450MeV_uerrs[i])}\n")

with open("/Users/christianschmidt/Desktop/chargedk2_CE500MeV_NORM.csv", "w") as file:
    file.write("Nch/Nch05,k2,Nch/Nch05err,k2lerr,k2uerr\n")
    for i in range(len(multiplicitycharged_THRESHOLD500MeV_vals_05)):
        file.write(f"{float(multiplicitycharged_THRESHOLD500MeV_vals_05[i])},{float(pTfluctuationschargedk2_THRESHOLD500MeV_vals[i])},{float(multiplicitycharged_THRESHOLD500MeV_symerrs_05[i])},{float(pTfluctuationschargedk2_THRESHOLD500MeV_lerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD500MeV_uerrs[i])}\n")

with open("/Users/christianschmidt/Desktop/chargedk2_CE550MeV_NORM.csv", "w") as file:
    file.write("Nch/Nch05,k2,Nch/Nch05err,k2lerr,k2uerr\n")
    for i in range(len(multiplicitycharged_THRESHOLD550MeV_vals_05)):
        file.write(f"{float(multiplicitycharged_THRESHOLD550MeV_vals_05[i])},{float(pTfluctuationschargedk2_THRESHOLD550MeV_vals[i])},{float(multiplicitycharged_THRESHOLD550MeV_symerrs_05[i])},{float(pTfluctuationschargedk2_THRESHOLD550MeV_lerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD550MeV_uerrs[i])}\n")


# with open("/Users/christianschmidt/Desktop/chargedk2_CE600MeV_NORM.csv", "w") as file:
#     file.write("Nch/Nch05,k2,Nch/Nch05err,k2lerr,k2uerr\n")
#     for i in range(len(multiplicitycharged_THRESHOLD600MeV_vals_05)):
#         file.write(f"{float(multiplicitycharged_THRESHOLD600MeV_vals_05[i])},{float(pTfluctuationschargedk2_THRESHOLD600MeV_vals[i])},{float(multiplicitycharged_THRESHOLD600MeV_symerrs_05[i])},{float(pTfluctuationschargedk2_THRESHOLD600MeV_lerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD600MeV_uerrs[i])}\n")

# with open("/Users/christianschmidt/Desktop/chargedk2_CE800MeV_NORM.csv", "w") as file:
#     file.write("Nch/Nch05,k2,Nch/Nch05err,k2lerr,k2uerr\n")
#     for i in range(len(multiplicitycharged_THRESHOLD800MeV_vals_05)):
#         file.write(f"{float(multiplicitycharged_THRESHOLD800MeV_vals_05[i])},{float(pTfluctuationschargedk2_THRESHOLD800MeV_vals[i])},{float(multiplicitycharged_THRESHOLD800MeV_symerrs_05[i])},{float(pTfluctuationschargedk2_THRESHOLD800MeV_lerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD800MeV_uerrs[i])}\n")

# with open("/Users/christianschmidt/Desktop/chargedk2_CE1000MeV_NORM.csv", "w") as file:
#     file.write("Nch/Nch05,k2,Nch/Nch05err,k2lerr,k2uerr\n")
#     for i in range(len(multiplicitycharged_THRESHOLD1000MeV_vals_05)):
#         file.write(f"{float(multiplicitycharged_THRESHOLD1000MeV_vals_05[i])},{float(pTfluctuationschargedk2_THRESHOLD1000MeV_vals[i])},{float(multiplicitycharged_THRESHOLD1000MeV_symerrs_05[i])},{float(pTfluctuationschargedk2_THRESHOLD1000MeV_lerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD1000MeV_uerrs[i])}\n")
# Out:
# /var/folders/mb/30yyqfg516jdbq01t3whp1r40000gn/T/ipykernel_2857/4156275708.py:14: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   file.write(f"{float(multiplicitycharged_THRESHOLD450MeV_vals_05[i])},{float(pTfluctuationschargedk2_THRESHOLD450MeV_vals[i])},{float(multiplicitycharged_THRESHOLD450MeV_symerrs_05[i])},{float(pTfluctuationschargedk2_THRESHOLD450MeV_lerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD450MeV_uerrs[i])}\n")
# /var/folders/mb/30yyqfg516jdbq01t3whp1r40000gn/T/ipykernel_2857/4156275708.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
# ...

# %%
# with open("/Users/christianschmidt/Desktop/chargedk2_CE200MeV.csv", "w") as file:
#     file.write("Nch,k2,Ncherr,k2lerr,k2uerr\n")
#     for i in range(len(multiplicitycharged_THRESHOLD200MeV_vals)):
#         file.write(f"{float(multiplicitycharged_THRESHOLD200MeV_vals[i])},{float(pTfluctuationschargedk2_THRESHOLD200MeV_vals[i])},{float(multiplicitycharged_THRESHOLD200MeV_symerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD200MeV_lerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD200MeV_uerrs[i])}\n")

# with open("/Users/christianschmidt/Desktop/chargedk2_CE400MeV.csv", "w") as file:
#     file.write("Nch,k2,Ncherr,k2lerr,k2uerr\n")
#     for i in range(len(multiplicitycharged_THRESHOLD400MeV_vals)):
#         file.write(f"{float(multiplicitycharged_THRESHOLD400MeV_vals[i])},{float(pTfluctuationschargedk2_THRESHOLD400MeV_vals[i])},{float(multiplicitycharged_THRESHOLD400MeV_symerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD400MeV_lerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD400MeV_uerrs[i])}\n")

with open("/Users/christianschmidt/Desktop/chargedk2_CE450MeV.csv", "w") as file:
    file.write("Nch,k2,Ncherr,k2lerr,k2uerr\n")
    for i in range(len(multiplicitycharged_THRESHOLD450MeV_vals)):
        file.write(f"{float(multiplicitycharged_THRESHOLD450MeV_vals[i])},{float(pTfluctuationschargedk2_THRESHOLD450MeV_vals[i])},{float(multiplicitycharged_THRESHOLD450MeV_symerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD450MeV_lerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD450MeV_uerrs[i])}\n")

with open("/Users/christianschmidt/Desktop/chargedk2_CE500MeV.csv", "w") as file:
    file.write("Nch,k2,Ncherr,k2lerr,k2uerr\n")
    for i in range(len(multiplicitycharged_THRESHOLD500MeV_vals)):
        file.write(f"{float(multiplicitycharged_THRESHOLD500MeV_vals[i])},{float(pTfluctuationschargedk2_THRESHOLD500MeV_vals[i])},{float(multiplicitycharged_THRESHOLD500MeV_symerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD500MeV_lerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD500MeV_uerrs[i])}\n")

with open("/Users/christianschmidt/Desktop/chargedk2_CE550MeV.csv", "w") as file:
    file.write("Nch,k2,Ncherr,k2lerr,k2uerr\n")
    for i in range(len(multiplicitycharged_THRESHOLD550MeV_vals)):
        file.write(f"{float(multiplicitycharged_THRESHOLD550MeV_vals[i])},{float(pTfluctuationschargedk2_THRESHOLD550MeV_vals[i])},{float(multiplicitycharged_THRESHOLD550MeV_symerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD550MeV_lerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD550MeV_uerrs[i])}\n")

# with open("/Users/christianschmidt/Desktop/chargedk2_CE600MeV.csv", "w") as file:
#     file.write("Nch,k2,Ncherr,k2lerr,k2uerr\n")
#     for i in range(len(multiplicitycharged_THRESHOLD600MeV_vals)):
#         file.write(f"{float(multiplicitycharged_THRESHOLD600MeV_vals[i])},{float(pTfluctuationschargedk2_THRESHOLD600MeV_vals[i])},{float(multiplicitycharged_THRESHOLD600MeV_symerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD600MeV_lerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD600MeV_uerrs[i])}\n")

# with open("/Users/christianschmidt/Desktop/chargedk2_CE800MeV.csv", "w") as file:
#     file.write("Nch,k2,Ncherr,k2lerr,k2uerr\n")
#     for i in range(len(multiplicitycharged_THRESHOLD800MeV_vals)):
#         file.write(f"{float(multiplicitycharged_THRESHOLD800MeV_vals[i])},{float(pTfluctuationschargedk2_THRESHOLD800MeV_vals[i])},{float(multiplicitycharged_THRESHOLD800MeV_symerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD800MeV_lerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD800MeV_uerrs[i])}\n")

# with open("/Users/christianschmidt/Desktop/chargedk2_CE1000MeV.csv", "w") as file:
#     file.write("Nch,k2,Ncherr,k2lerr,k2uerr\n")
#     for i in range(len(multiplicitycharged_THRESHOLD1000MeV_vals)):
#         file.write(f"{float(multiplicitycharged_THRESHOLD1000MeV_vals[i])},{float(pTfluctuationschargedk2_THRESHOLD1000MeV_vals[i])},{float(multiplicitycharged_THRESHOLD1000MeV_symerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD1000MeV_lerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD1000MeV_uerrs[i])}\n")
# Out:
# /var/folders/mb/30yyqfg516jdbq01t3whp1r40000gn/T/ipykernel_2857/3745755333.py:14: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   file.write(f"{float(multiplicitycharged_THRESHOLD450MeV_vals[i])},{float(pTfluctuationschargedk2_THRESHOLD450MeV_vals[i])},{float(multiplicitycharged_THRESHOLD450MeV_symerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD450MeV_lerrs[i])},{float(pTfluctuationschargedk2_THRESHOLD450MeV_uerrs[i])}\n")
# /var/folders/mb/30yyqfg516jdbq01t3whp1r40000gn/T/ipykernel_2857/3745755333.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
# ...

# %%
# with open("/Users/christianschmidt/Desktop/chargedk3_CE200MeV_NORM.csv", "w") as file:
#     file.write("Nch/Nch05,k3,Nch/Nch05err,k3lerr,k3uerr\n")
#     for i in range(len(multiplicitycharged_THRESHOLD200MeV_vals_05)):
#         file.write(f"{float(multiplicitycharged_THRESHOLD200MeV_vals_05[i])},{float(pTfluctuationschargedk3_THRESHOLD200MeV_vals[i])},{float(multiplicitycharged_THRESHOLD200MeV_symerrs_05[i])},{float(pTfluctuationschargedk3_THRESHOLD200MeV_lerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD200MeV_uerrs[i])}\n")

# with open("/Users/christianschmidt/Desktop/chargedk3_CE400MeV_NORM.csv", "w") as file:
#     file.write("Nch/Nch05,k3,Nch/Nch05err,k3lerr,k3uerr\n")
#     for i in range(len(multiplicitycharged_THRESHOLD400MeV_vals_05)):
#         file.write(f"{float(multiplicitycharged_THRESHOLD400MeV_vals_05[i])},{float(pTfluctuationschargedk3_THRESHOLD400MeV_vals[i])},{float(multiplicitycharged_THRESHOLD400MeV_symerrs_05[i])},{float(pTfluctuationschargedk3_THRESHOLD400MeV_lerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD400MeV_uerrs[i])}\n")

with open("/Users/christianschmidt/Desktop/chargedk3_CE450MeV_NORM.csv", "w") as file:
    file.write("Nch/Nch05,k3,Nch/Nch05err,k3lerr,k3uerr\n")
    for i in range(len(multiplicitycharged_THRESHOLD450MeV_vals_05)):
        file.write(f"{float(multiplicitycharged_THRESHOLD450MeV_vals_05[i])},{float(pTfluctuationschargedk3_THRESHOLD450MeV_vals[i])},{float(multiplicitycharged_THRESHOLD450MeV_symerrs_05[i])},{float(pTfluctuationschargedk3_THRESHOLD450MeV_lerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD450MeV_uerrs[i])}\n")

with open("/Users/christianschmidt/Desktop/chargedk3_CE500MeV_NORM.csv", "w") as file:
    file.write("Nch/Nch05,k3,Nch/Nch05err,k3lerr,k3uerr\n")
    for i in range(len(multiplicitycharged_THRESHOLD500MeV_vals_05)):
        file.write(f"{float(multiplicitycharged_THRESHOLD500MeV_vals_05[i])},{float(pTfluctuationschargedk3_THRESHOLD500MeV_vals[i])},{float(multiplicitycharged_THRESHOLD500MeV_symerrs_05[i])},{float(pTfluctuationschargedk3_THRESHOLD500MeV_lerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD500MeV_uerrs[i])}\n")

with open("/Users/christianschmidt/Desktop/chargedk3_CE550MeV_NORM.csv", "w") as file:
    file.write("Nch/Nch05,k3,Nch/Nch05err,k3lerr,k3uerr\n")
    for i in range(len(multiplicitycharged_THRESHOLD550MeV_vals_05)):
        file.write(f"{float(multiplicitycharged_THRESHOLD550MeV_vals_05[i])},{float(pTfluctuationschargedk3_THRESHOLD550MeV_vals[i])},{float(multiplicitycharged_THRESHOLD550MeV_symerrs_05[i])},{float(pTfluctuationschargedk3_THRESHOLD550MeV_lerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD550MeV_uerrs[i])}\n")

# with open("/Users/christianschmidt/Desktop/chargedk3_CE600MeV_NORM.csv", "w") as file:
#     file.write("Nch/Nch05,k3,Nch/Nch05err,k3lerr,k3uerr\n")
#     for i in range(len(multiplicitycharged_THRESHOLD600MeV_vals_05)):
#         file.write(f"{float(multiplicitycharged_THRESHOLD600MeV_vals_05[i])},{float(pTfluctuationschargedk3_THRESHOLD600MeV_vals[i])},{float(multiplicitycharged_THRESHOLD600MeV_symerrs_05[i])},{float(pTfluctuationschargedk3_THRESHOLD600MeV_lerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD600MeV_uerrs[i])}\n")

# with open("/Users/christianschmidt/Desktop/chargedk3_CE800MeV_NORM.csv", "w") as file:
#     file.write("Nch/Nch05,k3,Nch/Nch05err,k3lerr,k3uerr\n")
#     for i in range(len(multiplicitycharged_THRESHOLD800MeV_vals_05)):
#         file.write(f"{float(multiplicitycharged_THRESHOLD800MeV_vals_05[i])},{float(pTfluctuationschargedk3_THRESHOLD800MeV_vals[i])},{float(multiplicitycharged_THRESHOLD800MeV_symerrs_05[i])},{float(pTfluctuationschargedk3_THRESHOLD800MeV_lerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD800MeV_uerrs[i])}\n")

# with open("/Users/christianschmidt/Desktop/chargedk3_CE1000MeV_NORM.csv", "w") as file:
#     file.write("Nch/Nch05,k3,Nch/Nch05err,k3lerr,k3uerr\n")
#     for i in range(len(multiplicitycharged_THRESHOLD1000MeV_vals_05)):
#         file.write(f"{float(multiplicitycharged_THRESHOLD1000MeV_vals_05[i])},{float(pTfluctuationschargedk3_THRESHOLD1000MeV_vals[i])},{float(multiplicitycharged_THRESHOLD1000MeV_symerrs_05[i])},{float(pTfluctuationschargedk3_THRESHOLD1000MeV_lerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD1000MeV_uerrs[i])}\n")
# Out:
# /var/folders/mb/30yyqfg516jdbq01t3whp1r40000gn/T/ipykernel_2857/3546763684.py:14: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   file.write(f"{float(multiplicitycharged_THRESHOLD450MeV_vals_05[i])},{float(pTfluctuationschargedk3_THRESHOLD450MeV_vals[i])},{float(multiplicitycharged_THRESHOLD450MeV_symerrs_05[i])},{float(pTfluctuationschargedk3_THRESHOLD450MeV_lerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD450MeV_uerrs[i])}\n")
# /var/folders/mb/30yyqfg516jdbq01t3whp1r40000gn/T/ipykernel_2857/3546763684.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
# ...

# %%
# with open("/Users/christianschmidt/Desktop/chargedk3_CE200MeV.csv", "w") as file:
#     file.write("Nch,k3,Ncherr,k3lerr,k3uerr\n")
#     for i in range(len(multiplicitycharged_THRESHOLD200MeV_vals)):
#         file.write(f"{float(multiplicitycharged_THRESHOLD200MeV_vals[i])},{float(pTfluctuationschargedk3_THRESHOLD200MeV_vals[i])},{float(multiplicitycharged_THRESHOLD200MeV_symerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD200MeV_lerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD200MeV_uerrs[i])}\n")

# with open("/Users/christianschmidt/Desktop/chargedk3_CE400MeV.csv", "w") as file:
#     file.write("Nch,k3,Ncherr,k3lerr,k3uerr\n")
#     for i in range(len(multiplicitycharged_THRESHOLD400MeV_vals)):
#         file.write(f"{float(multiplicitycharged_THRESHOLD400MeV_vals[i])},{float(pTfluctuationschargedk3_THRESHOLD400MeV_vals[i])},{float(multiplicitycharged_THRESHOLD400MeV_symerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD400MeV_lerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD400MeV_uerrs[i])}\n")

with open("/Users/christianschmidt/Desktop/chargedk3_CE450MeV.csv", "w") as file:
    file.write("Nch,k3,Ncherr,k3lerr,k3uerr\n")
    for i in range(len(multiplicitycharged_THRESHOLD450MeV_vals)):
        file.write(f"{float(multiplicitycharged_THRESHOLD450MeV_vals[i])},{float(pTfluctuationschargedk3_THRESHOLD450MeV_vals[i])},{float(multiplicitycharged_THRESHOLD450MeV_symerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD450MeV_lerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD450MeV_uerrs[i])}\n")

with open("/Users/christianschmidt/Desktop/chargedk3_CE500MeV.csv", "w") as file:
    file.write("Nch,k3,Ncherr,k3lerr,k3uerr\n")
    for i in range(len(multiplicitycharged_THRESHOLD500MeV_vals)):
        file.write(f"{float(multiplicitycharged_THRESHOLD500MeV_vals[i])},{float(pTfluctuationschargedk3_THRESHOLD500MeV_vals[i])},{float(multiplicitycharged_THRESHOLD500MeV_symerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD500MeV_lerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD500MeV_uerrs[i])}\n")

with open("/Users/christianschmidt/Desktop/chargedk3_CE550MeV.csv", "w") as file:
    file.write("Nch,k3,Ncherr,k3lerr,k3uerr\n")
    for i in range(len(multiplicitycharged_THRESHOLD550MeV_vals)):
        file.write(f"{float(multiplicitycharged_THRESHOLD550MeV_vals[i])},{float(pTfluctuationschargedk3_THRESHOLD550MeV_vals[i])},{float(multiplicitycharged_THRESHOLD550MeV_symerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD550MeV_lerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD550MeV_uerrs[i])}\n")

# with open("/Users/christianschmidt/Desktop/chargedk3_CE600MeV.csv", "w") as file:
#     file.write("Nch,k3,Ncherr,k3lerr,k3uerr\n")
#     for i in range(len(multiplicitycharged_THRESHOLD600MeV_vals)):
#         file.write(f"{float(multiplicitycharged_THRESHOLD600MeV_vals[i])},{float(pTfluctuationschargedk3_THRESHOLD600MeV_vals[i])},{float(multiplicitycharged_THRESHOLD600MeV_symerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD600MeV_lerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD600MeV_uerrs[i])}\n")

# with open("/Users/christianschmidt/Desktop/chargedk3_CE800MeV.csv", "w") as file:
#     file.write("Nch,k3,Ncherr,k3lerr,k3uerr\n")
#     for i in range(len(multiplicitycharged_THRESHOLD800MeV_vals)):
#         file.write(f"{float(multiplicitycharged_THRESHOLD800MeV_vals[i])},{float(pTfluctuationschargedk3_THRESHOLD800MeV_vals[i])},{float(multiplicitycharged_THRESHOLD800MeV_symerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD800MeV_lerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD800MeV_uerrs[i])}\n")

# with open("/Users/christianschmidt/Desktop/chargedk3_CE1000MeV.csv", "w") as file:
#     file.write("Nch,k3,Ncherr,k3lerr,k3uerr\n")
#     for i in range(len(multiplicitycharged_THRESHOLD1000MeV_vals)):
#         file.write(f"{float(multiplicitycharged_THRESHOLD1000MeV_vals[i])},{float(pTfluctuationschargedk3_THRESHOLD1000MeV_vals[i])},{float(multiplicitycharged_THRESHOLD1000MeV_symerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD1000MeV_lerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD1000MeV_uerrs[i])}\n")
# Out:
# /var/folders/mb/30yyqfg516jdbq01t3whp1r40000gn/T/ipykernel_2857/632560845.py:14: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   file.write(f"{float(multiplicitycharged_THRESHOLD450MeV_vals[i])},{float(pTfluctuationschargedk3_THRESHOLD450MeV_vals[i])},{float(multiplicitycharged_THRESHOLD450MeV_symerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD450MeV_lerrs[i])},{float(pTfluctuationschargedk3_THRESHOLD450MeV_uerrs[i])}\n")
# /var/folders/mb/30yyqfg516jdbq01t3whp1r40000gn/T/ipykernel_2857/632560845.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
# ...
